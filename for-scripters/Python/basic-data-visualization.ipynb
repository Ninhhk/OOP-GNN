# %% [markdown]
# <a href="https://colab.research.google.com/github/Ninhhk/OOP-GNN/blob/master/for-scripters/Python/basic-data-visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Data Visualization
# Kozo Nishida and Barry Demchak
#
# 2023-05-30
#
# **Cytoscape is an open source software platform for integrating, visualizing, and analyzing measurement data in the context of networks.**
#
# This tutorial presents a scenario of how expression and network data can be combined to tell a biological story and includes these concepts:
#
# *   Visualizing networks using expression data.
# *   Filtering networks based on expression data.
# *   Assessing expression data in the context of a biological network.
#
# ## Installation
#
# First, launch [Cytoscape Desktop](https://cytoscape.org/) and install the [FileTransfer App](http://apps.cytoscape.org/apps/filetransfer).
#
# Then run the following chunk of code below to install the `py4cytoscape` module.

# %%
# %%capture
# !python3 -m pip install python-igraph requests pandas networkx
# !python3 -m pip install py4cytoscape
import IPython
import py4cytoscape as p4c

# %% [markdown]
# If you are using a remote notebook environment such as Google Colab, please execute the cell below. (If you're running on your local notebook, you don't need to do that.)

# %%
#_PY4CYTOSCAPE = 'git+https://github.com/cytoscape/py4cytoscape@1.7.0' # optional
import requests
exec(requests.get("https://raw.githubusercontent.com/cytoscape/jupyter-bridge/master/client/p4c_init.py").text)
IPython.display.Javascript(_PY4CYTOSCAPE_BROWSER_CLIENT_JS) # Start browser client
# Out:
# Loading Javascript client ... 6ac6c8fd-590f-480e-8dbc-592e8a307998 on https://jupyter-bridge.cytoscape.org
# ADVICE: WHEN RUNNING UNDER COLAB, DO NOT RE-RUN THIS CELL WITHOUT MANUALLY EXECUTING Runtime | Factory Reset Runtime FROM THE COLAB MENU FIRST.

# %%
p4c.cytoscape_version_info()
# Out:
# DEBUG:py4...:Calling cytoscape_version_info()
# DEBUG:py4...:ǀCalling cyrest_get('version', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:Attempting to direct connect to Cytoscape on http://127.0.0.1:1234/v1
# DEBUG:py4...:Attempting to connect to remote Cytoscape because of error HTTPConnectionPool(host='127.0.0.1', port=1234): Max retries exceeded with url: /v1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ffa144a03d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# DEBUG:py4...:ǀHTTP GET(http://127.0.0.1:1234/v1)
# DEBUG:py4...:ǀOK[200], content: {"allAppsStarted":true,"apiVersion":"v1","numberOfCores":16,"memoryStatus":{"usedMemory":138,"freeMemory":1909,"totalMemory":2048,"maxMemory":14832}}
# DEBUG:py4...:Detected Cytoscape via Jupyter-Bridge
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/setSandbox), json: {'sandboxName': 'default_sandbox', 'copySamples': True, 'reinitialize': True}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"sandboxPath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox"},
#  "errors":[]
# }
# DEBUG:py4...:ǀHTTP GET(http://127.0.0.1:1234/v1/version)
# DEBUG:py4...:ǀOK[200], content: {"apiVersion":"v1","cytoscapeVersion":"3.10.2"}
# DEBUG:py4...:ǀReturning 'cyrest_get': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2'}
# DEBUG:py4...:HTTP version()
# DEBUG:py4...:OK[200], content: {"jupyterBridgeVersion":"0.0.2"}
# DEBUG:py4...:Returning 'cytoscape_version_info': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:--------------------
# {'apiVersion': 'v1',
#  'cytoscapeVersion': '3.10.2',
#  'automationAPIVersion': '1.11.0',
#  'py4cytoscapeVersion': '1.11.0',
#  'jupyterBridgeVersion': '0.0.2'}

# %% [markdown]
# ## Loading Network
#
# Let’s open a Cytoscape demo session file:

# %%
p4c.open_session()
# Out:
# DEBUG:py4...:Calling open_session()
# DEBUG:py4...:ǀCalling commands_post('session open file="sampleData/sessions/Yeast Perturbation.cys"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/session/open), json: {'file': 'sampleData/sessions/Yeast Perturbation.cys'}
# Opening sampleData/sessions/Yeast Perturbation.cys...
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {}
# DEBUG:py4...:Returning 'open_session': {}
# DEBUG:py4...:--------------------
# {}

# %% [markdown]
# ## Visualizing Expression Data on Networks
#
# Probably the most common use of expression data in Cytoscape is to set the **visual properties** of the nodes (color, shape, border) in a network according to expression data. This creates a powerful visualization, portraying functional relation and experimental response at the same time. Here, we will show an example of doing this.
#
# The data used in this example is from yeast, and represents an experiment of perturbations of the genes **Gal1**, **Gal4**, and **Gal80**, which are all yeast transcription factors. For this tutorial, the experimental data was part of the Cytoscape session file you loaded earlier, and is visible in the Node Table:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   You can select nodes in the network by

# %%
p4c.select_nodes(['YDL194W', 'YLR345W'], by_col='name')
# Out:
# DEBUG:py4...:Calling select_nodes(['YDL194W', 'YLR345W'], by_col='name')
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀCalling commands_post('network select network=SUID:"308" nodeList="name:YDL194W,name:YLR345W"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/select), json: {'network': 'SUID:308', 'nodeList': 'name:YDL194W,name:YLR345W'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"nodes":[
#   335,
#   349
# ], "edges":[]},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'nodes': [335, 349], 'edges': []}
# DEBUG:py4...:Returning 'select_nodes': {'nodes': [335, 349], 'edges': []}
# DEBUG:py4...:--------------------
# {'nodes': [335, 349], 'edges': []}

# %% [markdown]
# We can now use the data to manipulate the visual properties of the network by mapping specific data columns to visual style properties:
#
# *   The **gal80Rexp** expression values will be mapped to node color; nodes with low expression will be colored blue, nodes with high expression will be colored red.
# *   Significance for expression values will be mapped to Node Border Width, so nodes with significant changes will appear with a thicker border.
#
# ## Set Node Fill Color
#
# *   Click on the **Style** tab in the Control Panel. And you can set node fill color by

# %%
p4c.set_node_color_mapping(**p4c.gen_node_color_map('gal80Rexp', p4c.palette_color_brewer_d_RdBu(), style_name="galFiltered Style"))
# Out:
# DEBUG:py4...:Calling gen_node_color_map('gal80Rexp', ('palette_color_brewer_d_RdBu', 'divergent', <function palette_color_brewer_d_RdBu.<locals>.<lambda> at 0x7ffa144a48b0>), style_name='galFiltered Style')
# DEBUG:py4...:ǀCalling get_table_columns(table='node', columns='gal80Rexp', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling get_table_column_types('node', namespace='default', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀǀReturning 'get_table_column_types': {'SUID': 'Long', 'shared name': 'String', 'name': 'String', 'selected': 'Boolean', 'AverageShortestPathLength': 'Double', 'BetweennessCentrality': 'Double', 'ClosenessCentrality': 'Double', 'ClusteringCoefficient': 'Double', 'Degree': 'Integer', 'Eccentricity': 'Integer', 'IsSingleNode': 'Boolean', 'NeighborhoodConnectivity': 'Double', 'NumberOfDirectedEdges': 'Integer', 'NumberOfUndirectedE
, 1.345, -0.723, 0.124, 0.29, -0.172, -0.271, -0.339, -0.62, -0.89, -0.184, 0.109, -0.146, -0.394, -0.217, -0.214, -0.171, -0.084, -0.746, -0.022, 0.234, 0.571, -0.453, 0.339, -0.063, -0.046, 0.593, 0.0, 0.182, -0.134, -0.012, -0.177, -0.17, 0.576, 0.275, 0.393, 0.594, 0.883, 0.647, 0.33, 0.294, -0.269, -0.243, 0.397, 0.151, -0.052, 0.301, 0.057, 0.077, 0.106, -0.091, -0.064, 0.181, 0.525, -0.34, -0.487, 0.084, 0.839, -0.208, 0.802, 0.46, 0.795, -0.171, -0.462, 0.623, -0.169, 0.281, 0.579, -0.036, 0.716, -0.146, -0.379, 0.124, -0.661, 0.354, -0.058, -0.151, -0.002, -0.128, 0.202, 0.044, -0.302, -0.278, 0.92, -0.769, -0.08, -0.91, -0.069, 0.008, 0.483, -0.018, -0.301, 0.187, 0.355, 0.292, 0.498, 0.941, 0.378, 0.708, 0.199, 0.057, 0.331, 0.43, 0.627, 0.222, 0.254, 0.357, 0.225, -0.135, -0.591]}
# DEBUG:py4...:ǀReturning 'get_table_columns':      gal80Rexp
# 513      0.070
# 515     -0.826
# 517     -0.026
# 519      0.789
# 521     -0.253
# ..         ...
# 503      0.254
# 505      0.357
# 507      0.225
# 509     -0.135
# 511     -0.591
#
# [330 rows x 1 columns]
# DEBUG:py4...:Returning 'gen_node_color_map': {'table_column': 'gal80Rexp', 'table_column_values': [-3.126, 0.0, 3.126], 'colors': ['#67A9CF', '#F7F7F7', '#EF8A62'], 'mapping_type': 'c', 'default_color': None, 'style_name': 'galFiltered Style', 'network': None, 'base_url': 'http://127.0.0.1:1234/v1'}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling set_node_color_mapping(table_column='gal80Rexp', table_column_values=[-3.126, 0.0, 3.126], colors=['#67A9CF', '#F7F7F7', '#EF8A62'], mapping_type='c', default_color=None, style_name='galFiltered Style', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀCalling get_table_column_names('node', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀReturning 'get_table_column_names': ['SUID', 'shared name', 'name', 'selected', 'AverageShortestPathLength', 'BetweennessCentrality', 'ClosenessCentrality', 'ClusteringCoefficient', 'Degree', 'Eccentricity', 'IsSingleNode', 'NeighborhoodConnectivity', 'NumberOfDirectedEdges', 'NumberOfUndirectedEdges', 'PartnerOfMultiEdgedNodePairs', 'Radiality', 'SelfLoops', 'Stress', 'TopologicalCoefficient', 'degree.layout', 'COMMON', 'gal1RGexp', 'gal4RGexp', 'gal80Rexp', 'gal1RGsig', 'gal4RGsig', 'gal80Rsig', 'isExcludedFromPaths']
# DEBUG:py4...:ǀCalling map_visual_property('NODE_FILL_COLOR', 'gal80Rexp', 'c', [-3.126, 0.0, 3.126], ['#67A9CF', '#F7F7F7', '#EF8A62'], network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling get_visual_property_names(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling cyrest_get('styles/default/defaults', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/styles/default/defaults)
# DEBUG:py4...:ǀǀǀOK[200], content: {
#   "defaults" : [ {
#     "visualProperty" : "COMPOUND_NODE_PADDING",
#     "value" : 10.0
#   }, {
#     "visualProperty" : "COMPOUND_NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "DING_RENDERING_ENGINE_ROOT",
#     "value" : "org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@4823dee5"
#   }, {
#     "visualProperty" : "EDGE",
#     "value" : "DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)"
#   }, {
#     "visualProperty" : "EDGE_BEND",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_CURVED",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_LABEL_AUTOROTATE",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_COLOR",
#     "value" : "#B6B6B6"
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,10"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_SIZE",
#     "value" : 10
#   }, {
#     "visualProperty" : "EDGE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "EDGE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "EDGE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "EDGE_PAINT",
#     "value" : "#323232"
#   }, {
#     "visualProperty" : "EDGE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_STACKING",
#     "value" : "AUTO_BEND"
#   }, {
#     "visualProperty" : "EDGE_STACKING_DENSITY",
#     "value" : 0.5
#   }, {
#     "visualProperty" : "EDGE_STROKE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_STROKE_UNSELECTED_PAINT",
#     "value" : "#666666"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_UNSELECTED_PAINT",
#     "value" : "#404040"
#   }, {
#     "visualProperty" : "EDGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_WIDTH",
#     "value" : 3.0
#   }, {
#     "visualProperty" : "EDGE_Z_ORDER",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK",
#     "value" : "DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)"
#   }, {
#     "visualProperty" : "NETWORK_ANNOTATION_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_BACKGROUND_PAINT",
#     "value" : "#FFFFFF"
#   }, {
#     "visualProperty" : "NETWORK_CENTER_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Z_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_EDGE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_FORCE_HIGH_DETAIL",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_HEIGHT",
#     "value" : 400.0
#   }, {
#     "visualProperty" : "NETWORK_NODE_LABEL_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_NODE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_SCALE_FACTOR",
#     "value" : 1.0
#   }, {
#     "visualProperty" : "NETWORK_SIZE",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NETWORK_TITLE",
#     "value" : ""
#   }, {
#     "visualProperty" : "NETWORK_WIDTH",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NODE",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)"
#   }, {
#     "visualProperty" : "NODE_BORDER_PAINT",
#     "value" : "#006699"
#   }, {
#     "visualProperty" : "NODE_BORDER_STROKE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "NODE_BORDER_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_BORDER_WIDTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_1",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_2",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_3",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_4",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_5",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_6",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_7",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_8",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_9",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_1",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_2",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_3",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_4",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_5",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_6",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_7",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_8",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_9",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_1",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_2",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_3",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_4",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_5",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_6",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_7",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_8",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_9",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_1",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_1, name=Node Custom Paint 1)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_2",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_2, name=Node Custom Paint 2)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_3",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_3, name=Node Custom Paint 3)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_4",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_4, name=Node Custom Paint 4)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_5",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_5, name=Node Custom Paint 5)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_6",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_6, name=Node Custom Paint 6)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_7",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_7, name=Node Custom Paint 7)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_8",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_8, name=Node Custom Paint 8)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_9",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_9, name=Node Custom Paint 9)"
#   }, {
#     "visualProperty" : "NODE_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_FILL_COLOR",
#     "value" : "#33FFFF"
#   }, {
#     "visualProperty" : "NODE_HEIGHT",
#     "value" : 30.0
#   }, {
#     "visualProperty" : "NODE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_COLOR",
#     "value" : "#B6B6B6"
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_COLOR",
#     "value" : "#333333"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,12"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_SIZE",
#     "value" : 12
#   }, {
#     "visualProperty" : "NODE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "NODE_NESTED_NETWORK_IMAGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_PAINT",
#     "value" : "#1E90FF"
#   }, {
#     "visualProperty" : "NODE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "NODE_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "NODE_SIZE",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_WIDTH",
#     "value" : 70.0
#   }, {
#     "visualProperty" : "NODE_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Z_LOCATION",
#     "value" : 0.0
#   } ]
# }
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': {'defaults': [{'visualProperty': 'COMPOUND_NODE_PADDING', 'value': 10.0}, {'visualProperty': 'COMPOUND_NODE_SHAPE', 'value': 'ROUND_RECTANGLE'}, {'visualProperty': 'DING_RENDERING_ENGINE_ROOT', 'value': 'org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@4823dee5'}, {'visualProperty': 'EDGE', 'value': 'DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)'}, {'visualProperty': 'EDGE_BEND', 'value': ''}, {'visualProperty': 'EDGE_CURVED', 'value': True}, {'visualProperty': 'EDGE_LABEL', 'value': ''}, {'visualProperty': 'EDGE_LABEL_AUTOROTATE', 'value': False}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_COLOR', 'value': '#B6B6B6'}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_COLOR', 'value': '#000000'}, {'visualProperty': 'EDGE_LABEL_FONT_FACE', 'value': 'Dialog.plain,plain,10'}, {'visualProperty': 'EDGE_LABEL_FONT_SIZE', 'value': 10}, {'visualProperty': 'EDGE_LABEL_POSITION', 'value': 'C,C,c,0.00,0.00'}, {'visualProperty': 'EDGE_LABEL_ROTATION', 'value': 0.0}, {'visualProperty': 'EDGE_LABEL_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_WIDTH', 'value': 200.0}, {'visualProperty': 'EDGE_LINE_TYPE', 'value': 'SOLID'}, {'visualProperty': 'EDGE_PAINT', 'value': '#323232'}, {'visualProperty': 'EDGE_SELECTED', 'value': False}, {'visualProperty': 'EDGE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_STACKING', 'value': 'AUTO_BEND'}, {'visualProperty': 'EDGE_STACKING_DENSITY', 'value': 0.5}, {'visualProperty': 'EDGE_STROKE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_STROKE_UNSELECTED_PAINT', 'value': '#666666'}, {'visualProperty': 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_TARGET_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_TARGET_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_TOOLTIP', 'value': ''}, {'visualProperty': 'EDGE_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#404040'}, {'visualProperty': 'EDGE_VISIBLE', 'value': True}, {'visualProperty': 'EDGE_WIDTH', 'value': 3.0}, {'visualProperty': 'EDGE_Z_ORDER', 'value': 0.0}, {'visualProperty': 'NETWORK', 'value': 'DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)'}, {'visualProperty': 'NETWORK_ANNOTATION_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_BACKGROUND_PAINT', 'value': '#FFFFFF'}, {'visualProperty': 'NETWORK_CENTER_X_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Y_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Z_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_DEPTH', 'value': 0.0}, {'visualProperty': 'NETWORK_EDGE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_FORCE_HIGH_DETAIL', 'value': False}, {'visualProperty': 'NETWORK_HEIGHT', 'value': 400.0}, {'visualProperty': 'NETWORK_NODE_LABEL_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_NODE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_SCALE_FACTOR', 'value': 1.0}, {'visualProperty': 'NETWORK_SIZE', 'value': 550.0}, {'visualProperty': 'NETWORK_TITLE', 'value': ''}, {'visualProperty': 'NETWORK_WIDTH', 'value': 550.0}, {'visualProperty': 'NODE', 'value': 'DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)'}, {'visualProperty': 'NODE_BORDER_PAINT', 'value': '#006699'}, {'visualProperty': 'NODE_BORDER_STROKE', 'value': 'SOLID'}, {'visualProperty': 'NODE_BORDER_TRANSPARENCY', 'value': 255}, {'visualProperty': 'NODE_BORDER_ ...
# DEBUG:py4...:ǀǀReturning 'get_visual_property_names': ['COMPOUND_NODE_PADDING', 'COMPOUND_NODE_SHAPE', 'DING_RENDERING_ENGINE_ROOT', 'EDGE', 'EDGE_BEND', 'EDGE_CURVED', 'EDGE_LABEL', 'EDGE_LABEL_AUTOROTATE', 'EDGE_LABEL_BACKGROUND_COLOR', 'EDGE_LABEL_BACKGROUND_SHAPE', 'EDGE_LABEL_BACKGROUND_TRANSPARENCY', 'EDGE_LABEL_COLOR', 'EDGE_LABEL_FONT_FACE', 'EDGE_LABEL_FONT_SIZE', 'EDGE_LABEL_POSITION', 'EDGE_LABEL_ROTATION', 'EDGE_LABEL_TRANSPARENCY', 'EDGE_LABEL_WIDTH', 'EDGE_LINE_TYPE', 'EDGE_PAINT', 'EDGE_SELECTED', 'EDGE_SELECTED_PAINT', 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'EDGE_SOURCE_ARROW_SHAPE', 'EDGE_SOURCE_ARROW_SIZE', 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'EDGE_STACKING', 'EDGE_STACKING_DENSITY', 'EDGE_STROKE_SELECTED_PAINT', 'EDGE_STROKE_UNSELECTED_PAINT', 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'EDGE_TARGET_ARROW_SHAPE', 'EDGE_TARGET_ARROW_SIZE', 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'EDGE_TOOLTIP', 'EDGE_TRANSPARENCY', 'EDGE_UNSELECTED_PAINT', 'EDGE_VISIBLE', 'EDGE_WIDTH', 'EDGE_Z_ORDER', 'NETWORK', 'NETWORK_ANNOTATION_SELECTION', 'NETWORK_BACKGROUND_PAINT', 'NETWORK_CENTER_X_LOCATION', 'NETWORK_CENTER_Y_LOCATION', 'NETWORK_CENTER_Z_LOCATION', 'NETWORK_DEPTH', 'NETWORK_EDGE_SELECTION', 'NETWORK_FORCE_HIGH_DETAIL', 'NETWORK_HEIGHT', 'NETWORK_NODE_LABEL_SELECTION', 'NETWORK_NODE_SELECTION', 'NETWORK_SCALE_FACTOR', 'NETWORK_SIZE', 'NETWORK_TITLE', 'NETWORK_WIDTH', 'NODE', 'NODE_BORDER_PAINT', 'NODE_BORDER_STROKE', 'NODE_BORDER_TRANSPARENCY', 'NODE_BORDER_WIDTH', 'NODE_CUSTOMGRAPHICS_1', 'NODE_CUSTOMGRAPHICS_2', 'NODE_CUSTOMGRAPHICS_3', 'NODE_CUSTOMGRAPHICS_4', 'NODE_CUSTOMGRAPHICS_5', 'NODE_CUSTOMGRAPHICS_6', 'NODE_CUSTOMGRAPHICS_7', 'NODE_CUSTOMGRAPHICS_8', 'NODE_CUSTOMGRAPHICS_9', 'NODE_CUSTOMGRAPHICS_POSITION_1', 'NODE_CUSTOMGRAPHICS_POSITION_2', 'NODE_CUSTOMGRAPHICS_POSITION_3', 'NODE_CUSTOMGRAPHICS_POSITION_4', 'NODE_CUSTOMGRAPHICS_POSITION_5', 'NODE_CUSTOMGRAPHICS_POSITION_6', 'NODE_CUSTOMGRAPHICS_POSITION_7', 'NODE_CUSTOMGRAPHICS_POSITION_8', 'NODE_CUSTOMGRAPHICS_POSITION_9', 'NODE_CUSTOMGRAPHICS_SIZE_1', 'NODE_CUSTOMGRAPHICS_SIZE_2', 'NODE_CUSTOMGRAPHICS_SIZE_3', 'NODE_CUSTOMGRAPHICS_SIZE_4', 'NODE_CUSTOMGRAPHICS_SIZE_5', 'NODE_CUSTOMGRAPHICS_SIZE_6', 'NODE_CUSTOMGRAPHICS_SIZE_7', 'NODE_CUSTOMGRAPHICS_SIZE_8', 'NODE_CUSTOMGRAPHICS_SIZE_9', 'NODE_CUSTOMPAINT_1', 'NODE_CUSTOMPAINT_2', 'NODE_CUSTOMPAINT_3', 'NODE_CUSTOMPAINT_4', 'NODE_CUSTOMPAINT_5', 'NODE_CUSTOMPAINT_6', 'NODE_CUSTOMPAINT_7', 'NODE_CUSTOMPAINT_8', 'NODE_CUSTOMPAINT_9', 'NODE_DEPTH', 'NODE_FILL_COLOR', 'NODE_HEIGHT', 'NODE_LABEL', 'NODE_LABEL_BACKGROUND_COLOR', 'NODE_LABEL_BACKGROUND_SHAPE', 'NODE_LABEL_BACKGROUND_TRANSPARENCY', 'NODE_LABEL_COLOR', 'NODE_LABEL_FONT_FACE', 'NODE_LABEL_FONT_SIZE', 'NODE_LABEL_POSITION', 'NODE_LABEL_ROTATION', 'NODE_LABEL_TRANSPARENCY', 'NODE_LABEL_WIDTH', 'NODE_NESTED_NETWORK_IMAGE_VISIBLE', 'NODE_PAINT', 'NODE_SELECTED', 'NODE_SELECTED_PAINT', 'NODE_SHAPE', 'NODE_SIZE', 'NODE_TOOLTIP', 'NODE_TRANSPARENCY', 'NODE_VISIBLE', 'NODE_WIDTH', 'NODE_X_LOCATION', 'NODE_Y_LOCATION', 'NODE_Z_LOCATION']
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀReturning 'map_visual_property': {'mappingType': 'continuous', 'mappingColumn': 'gal80Rexp', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_FILL_COLOR', 'points': [{'value': -3.126, 'lesser': '#67A9CF', 'equal': '#67A9CF', 'greater': '#67A9CF'}, {'value': 0.0, 'lesser': '#F7F7F7', 'equal': '#F7F7F7', 'greater': '#F7F7F7'}, {'value': 3.126, 'lesser': '#EF8A62', 'equal': '#EF8A62', 'greater': '#EF8A62'}]}
# DEBUG:py4...:ǀCalling update_style_mapping('galFiltered Style', {'mappingType': 'continuous', 'mappingColumn': 'gal80Rexp', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_FILL_COLOR', 'points': [{'value': -3.126, 'lesser': '#67A9CF', 'equal': '#67A9CF', 'greater': '#67A9CF'}, {'value': 0.0, 'lesser': '#F7F7F7', 'equal': '#F7F7F7', 'greater': '#F7F7F7'}, {'value': 3.126, 'lesser': '#EF8A62', 'equal': '#EF8A62', 'greater': '#EF8A62'}]}, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('styles/galFiltered Style/mappings', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/styles/galFiltered%20Style/mappings)
# DEBUG:py4...:ǀǀOK[200], content: [ {
#   "mappingType" : "continuous",
#   "mappingColumn" : "degree.layout",
#   "mappingColumnType" : "Number",
#   "visualProperty" : "NODE_SIZE",
#   "points" : [ {
#     "value" : 1.0,
#     "lesser" : "1.0",
#     "equal" : "40.0",
#     "greater" : "40.0"
#   }, {
#     "value" : 18.0,
#     "lesser" : "150.0",
#     "equal" : "150.0",
#     "greater" : "1.0"
#   } ]
# }, {
#   "mappingType" : "continuous",
#   "mappingColumn" : "gal1RGexp",
#   "mappingColumnType" : "Number",
#   "visualProperty" : "NODE_FILL_COLOR",
#   "points" : [ {
#     "value" : -2.426,
#     "lesser" : "#0066CC",
#     "equal" : "#0066CC",
#     "greater" : "#0066CC"
#   }, {
#     "value" : 1.225471493171426E-7,
#     "lesser" : "#FFFFFF",
#     "equal" : "#FFFFFF",
#     "greater" : "#FFFFFF"
#   }, {
#     "value" : 2.058,
#     "lesser" : "#FFFF00",
#     "equal" : "#FFFF00",
#     "greater" : "#FFFF00"
#   } ]
# }, {
#   "mappingType" : "passthrough",
#   "mappingColumn" : "COMMON",
#   "mappingColumnType" : "String",
#   "visualProperty" : "NODE_LABEL"
# }, {
#   "mappingType" : "continuous",
#   "mappingColumn" : "Degree",
#   "mappingColumnType" : "Number",
#   "visualProperty" : "NODE_LABEL_FONT_SIZE",
#   "points" : [ {
#     "value" : 1.0,
#     "lesser" : "1",
#     "equal" : "10",
#     "greater" : "10"
#   }, {
#     "value" : 18.0,
#     "lesser" : "40",
#     "equal" : "40",
#     "greater" : "1"
#   } ]
# } ]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'mappingType': 'continuous', 'mappingColumn': 'degree.layout', 'mappingColumnType': 'Number', 'visualProperty': 'NODE_SIZE', 'points': [{'value': 1.0, 'lesser': '1.0', 'equal': '40.0', 'greater': '40.0'}, {'value': 18.0, 'lesser': '150.0', 'equal': '150.0', 'greater': '1.0'}]}, {'mappingType': 'continuous', 'mappingColumn': 'gal1RGexp', 'mappingColumnType': 'Number', 'visualProperty': 'NODE_FILL_COLOR', 'points': [{'value': -2.426, 'lesser': '#0066CC', 'equal': '#0066CC', 'greater': '#0066CC'}, {'value': 1.225471493171426e-07, 'lesser': '#FFFFFF', 'equal': '#FFFFFF', 'greater': '#FFFFFF'}, {'value': 2.058, 'lesser': '#FFFF00', 'equal': '#FFFF00', 'greater': '#FFFF00'}]}, {'mappingType': 'passthrough', 'mappingColumn': 'COMMON', 'mappingColumnType': 'String', 'visualProperty': 'NODE_LABEL'}, {'mappingType': 'continuous', 'mappingColumn': 'Degree', 'mappingColumnType': 'Number', 'visualProperty': 'NODE_LABEL_FONT_SIZE', 'points': [{'value': 1.0, 'lesser': '1', 'equal': '10', 'greater': '10'}, {'value': 18.0, 'lesser': '40', 'equal': '40', 'greater': '1'}]}]
# DEBUG:py4...:ǀǀCalling cyrest_put('styles/galFiltered Style/mappings/NODE_FILL_COLOR', body=[{'mappingType': 'continuous', 'mappingColumn': 'gal80Rexp', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_FILL_COLOR', 'points': [{'value': -3.126, 'lesser': '#67A9CF', 'equal': '#67A9CF', 'greater': '#67A9CF'}, {'value': 0.0, 'lesser': '#F7F7F7', 'equal': '#F7F7F7', 'greater': '#F7F7F7'}, {'value': 3.126, 'lesser': '#EF8A62', 'equal': '#EF8A62', 'greater': '#EF8A62'}]}], base_url='http://127.0.0.1:1234/v1', require_json=False)
# DEBUG:py4...:ǀǀHTTP PUT(http://127.0.0.1:1234/v1/styles/galFiltered%20Style/mappings/NODE_FILL_COLOR), json: [{'mappingType': 'continuous', 'mappingColumn': 'gal80Rexp', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_FILL_COLOR', 'points': [{'value': -3.126, 'lesser': '#67A9CF', 'equal': '#67A9CF', 'greater': '#67A9CF'}, {'value': 0.0, 'lesser': '#F7F7F7', 'equal': '#F7F7F7', 'greater': '#F7F7F7'}, {'value': 3.126, 'lesser': '#EF8A62', 'equal': '#EF8A62', 'greater': '#EF8A62'}]}]
# DEBUG:py4...:ǀǀOK[200], content:
# DEBUG:py4...:ǀǀReturning 'cyrest_put': ''
# DEBUG:py4...:ǀReturning 'update_style_mapping': ''
# DEBUG:py4...:Returning 'set_node_color_mapping': ''
# DEBUG:py4...:--------------------
# ''

# %% [markdown]
# Note: we are using paletteColorBrewerRdBu to generate a set of three standardized colors balanced for a divergent gradient (low, mid, high), which are automatically extracted from the gal80RExp column.

# %% [markdown]
# *   This produces an initial gradient ranging from blue to red for expression values. Notice that the nodes in the network change color.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Set Node Border Color and Width
#
# To visualize the significance of measurements, let’s add a contiuous mapping for ‘gal80Rsig’ p-values to Node Border Color:

# %%
p4c.set_node_border_color_mapping('gal80Rsig',[0,0.05], ["#FF0000","#FF0000","#FF0000","#555555"],style_name="galFiltered Style")
# Out:
# DEBUG:py4...:Calling set_node_border_color_mapping('gal80Rsig', [0, 0.05], ['#FF0000', '#FF0000', '#FF0000', '#555555'], style_name='galFiltered Style')
# DEBUG:py4...:ǀCalling get_table_column_names('node', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀReturning 'get_table_column_names': ['SUID', 'shared name', 'name', 'selected', 'AverageShortestPathLength', 'BetweennessCentrality', 'ClosenessCentrality', 'ClusteringCoefficient', 'Degree', 'Eccentricity', 'IsSingleNode', 'NeighborhoodConnectivity', 'NumberOfDirectedEdges', 'NumberOfUndirectedEdges', 'PartnerOfMultiEdgedNodePairs', 'Radiality', 'SelfLoops', 'Stress', 'TopologicalCoefficient', 'degree.layout', 'COMMON', 'gal1RGexp', 'gal4RGexp', 'gal80Rexp', 'gal1RGsig', 'gal4RGsig', 'gal80Rsig', 'isExcludedFromPaths']
# DEBUG:py4...:ǀCalling map_visual_property('NODE_BORDER_PAINT', 'gal80Rsig', 'c', [0, 0.05], ['#FF0000', '#FF0000', '#FF0000', '#555555'], network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling get_visual_property_names(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling cyrest_get('styles/default/defaults', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/styles/default/defaults)
# DEBUG:py4...:ǀǀǀOK[200], content: {
#   "defaults" : [ {
#     "visualProperty" : "COMPOUND_NODE_PADDING",
#     "value" : 10.0
#   }, {
#     "visualProperty" : "COMPOUND_NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "DING_RENDERING_ENGINE_ROOT",
#     "value" : "org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@4823dee5"
#   }, {
#     "visualProperty" : "EDGE",
#     "value" : "DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)"
#   }, {
#     "visualProperty" : "EDGE_BEND",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_CURVED",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_LABEL_AUTOROTATE",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_COLOR",
#     "value" : "#B6B6B6"
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,10"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_SIZE",
#     "value" : 10
#   }, {
#     "visualProperty" : "EDGE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "EDGE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "EDGE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "EDGE_PAINT",
#     "value" : "#323232"
#   }, {
#     "visualProperty" : "EDGE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_STACKING",
#     "value" : "AUTO_BEND"
#   }, {
#     "visualProperty" : "EDGE_STACKING_DENSITY",
#     "value" : 0.5
#   }, {
#     "visualProperty" : "EDGE_STROKE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_STROKE_UNSELECTED_PAINT",
#     "value" : "#666666"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_UNSELECTED_PAINT",
#     "value" : "#404040"
#   }, {
#     "visualProperty" : "EDGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_WIDTH",
#     "value" : 3.0
#   }, {
#     "visualProperty" : "EDGE_Z_ORDER",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK",
#     "value" : "DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)"
#   }, {
#     "visualProperty" : "NETWORK_ANNOTATION_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_BACKGROUND_PAINT",
#     "value" : "#FFFFFF"
#   }, {
#     "visualProperty" : "NETWORK_CENTER_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Z_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_EDGE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_FORCE_HIGH_DETAIL",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_HEIGHT",
#     "value" : 400.0
#   }, {
#     "visualProperty" : "NETWORK_NODE_LABEL_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_NODE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_SCALE_FACTOR",
#     "value" : 1.0
#   }, {
#     "visualProperty" : "NETWORK_SIZE",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NETWORK_TITLE",
#     "value" : ""
#   }, {
#     "visualProperty" : "NETWORK_WIDTH",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NODE",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)"
#   }, {
#     "visualProperty" : "NODE_BORDER_PAINT",
#     "value" : "#006699"
#   }, {
#     "visualProperty" : "NODE_BORDER_STROKE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "NODE_BORDER_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_BORDER_WIDTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_1",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_2",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_3",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_4",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_5",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_6",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_7",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_8",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_9",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_1",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_2",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_3",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_4",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_5",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_6",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_7",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_8",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_9",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_1",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_2",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_3",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_4",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_5",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_6",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_7",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_8",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_9",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_1",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_1, name=Node Custom Paint 1)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_2",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_2, name=Node Custom Paint 2)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_3",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_3, name=Node Custom Paint 3)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_4",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_4, name=Node Custom Paint 4)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_5",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_5, name=Node Custom Paint 5)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_6",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_6, name=Node Custom Paint 6)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_7",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_7, name=Node Custom Paint 7)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_8",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_8, name=Node Custom Paint 8)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_9",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_9, name=Node Custom Paint 9)"
#   }, {
#     "visualProperty" : "NODE_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_FILL_COLOR",
#     "value" : "#33FFFF"
#   }, {
#     "visualProperty" : "NODE_HEIGHT",
#     "value" : 30.0
#   }, {
#     "visualProperty" : "NODE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_COLOR",
#     "value" : "#B6B6B6"
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_COLOR",
#     "value" : "#333333"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,12"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_SIZE",
#     "value" : 12
#   }, {
#     "visualProperty" : "NODE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "NODE_NESTED_NETWORK_IMAGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_PAINT",
#     "value" : "#1E90FF"
#   }, {
#     "visualProperty" : "NODE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "NODE_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "NODE_SIZE",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_WIDTH",
#     "value" : 70.0
#   }, {
#     "visualProperty" : "NODE_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Z_LOCATION",
#     "value" : 0.0
#   } ]
# }
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': {'defaults': [{'visualProperty': 'COMPOUND_NODE_PADDING', 'value': 10.0}, {'visualProperty': 'COMPOUND_NODE_SHAPE', 'value': 'ROUND_RECTANGLE'}, {'visualProperty': 'DING_RENDERING_ENGINE_ROOT', 'value': 'org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@4823dee5'}, {'visualProperty': 'EDGE', 'value': 'DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)'}, {'visualProperty': 'EDGE_BEND', 'value': ''}, {'visualProperty': 'EDGE_CURVED', 'value': True}, {'visualProperty': 'EDGE_LABEL', 'value': ''}, {'visualProperty': 'EDGE_LABEL_AUTOROTATE', 'value': False}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_COLOR', 'value': '#B6B6B6'}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_COLOR', 'value': '#000000'}, {'visualProperty': 'EDGE_LABEL_FONT_FACE', 'value': 'Dialog.plain,plain,10'}, {'visualProperty': 'EDGE_LABEL_FONT_SIZE', 'value': 10}, {'visualProperty': 'EDGE_LABEL_POSITION', 'value': 'C,C,c,0.00,0.00'}, {'visualProperty': 'EDGE_LABEL_ROTATION', 'value': 0.0}, {'visualProperty': 'EDGE_LABEL_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_WIDTH', 'value': 200.0}, {'visualProperty': 'EDGE_LINE_TYPE', 'value': 'SOLID'}, {'visualProperty': 'EDGE_PAINT', 'value': '#323232'}, {'visualProperty': 'EDGE_SELECTED', 'value': False}, {'visualProperty': 'EDGE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_STACKING', 'value': 'AUTO_BEND'}, {'visualProperty': 'EDGE_STACKING_DENSITY', 'value': 0.5}, {'visualProperty': 'EDGE_STROKE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_STROKE_UNSELECTED_PAINT', 'value': '#666666'}, {'visualProperty': 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_TARGET_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_TARGET_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_TOOLTIP', 'value': ''}, {'visualProperty': 'EDGE_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#404040'}, {'visualProperty': 'EDGE_VISIBLE', 'value': True}, {'visualProperty': 'EDGE_WIDTH', 'value': 3.0}, {'visualProperty': 'EDGE_Z_ORDER', 'value': 0.0}, {'visualProperty': 'NETWORK', 'value': 'DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)'}, {'visualProperty': 'NETWORK_ANNOTATION_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_BACKGROUND_PAINT', 'value': '#FFFFFF'}, {'visualProperty': 'NETWORK_CENTER_X_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Y_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Z_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_DEPTH', 'value': 0.0}, {'visualProperty': 'NETWORK_EDGE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_FORCE_HIGH_DETAIL', 'value': False}, {'visualProperty': 'NETWORK_HEIGHT', 'value': 400.0}, {'visualProperty': 'NETWORK_NODE_LABEL_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_NODE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_SCALE_FACTOR', 'value': 1.0}, {'visualProperty': 'NETWORK_SIZE', 'value': 550.0}, {'visualProperty': 'NETWORK_TITLE', 'value': ''}, {'visualProperty': 'NETWORK_WIDTH', 'value': 550.0}, {'visualProperty': 'NODE', 'value': 'DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)'}, {'visualProperty': 'NODE_BORDER_PAINT', 'value': '#006699'}, {'visualProperty': 'NODE_BORDER_STROKE', 'value': 'SOLID'}, {'visualProperty': 'NODE_BORDER_TRANSPARENCY', 'value': 255}, {'visualProperty': 'NODE_BORDER_ ...
# DEBUG:py4...:ǀǀReturning 'get_visual_property_names': ['COMPOUND_NODE_PADDING', 'COMPOUND_NODE_SHAPE', 'DING_RENDERING_ENGINE_ROOT', 'EDGE', 'EDGE_BEND', 'EDGE_CURVED', 'EDGE_LABEL', 'EDGE_LABEL_AUTOROTATE', 'EDGE_LABEL_BACKGROUND_COLOR', 'EDGE_LABEL_BACKGROUND_SHAPE', 'EDGE_LABEL_BACKGROUND_TRANSPARENCY', 'EDGE_LABEL_COLOR', 'EDGE_LABEL_FONT_FACE', 'EDGE_LABEL_FONT_SIZE', 'EDGE_LABEL_POSITION', 'EDGE_LABEL_ROTATION', 'EDGE_LABEL_TRANSPARENCY', 'EDGE_LABEL_WIDTH', 'EDGE_LINE_TYPE', 'EDGE_PAINT', 'EDGE_SELECTED', 'EDGE_SELECTED_PAINT', 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'EDGE_SOURCE_ARROW_SHAPE', 'EDGE_SOURCE_ARROW_SIZE', 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'EDGE_STACKING', 'EDGE_STACKING_DENSITY', 'EDGE_STROKE_SELECTED_PAINT', 'EDGE_STROKE_UNSELECTED_PAINT', 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'EDGE_TARGET_ARROW_SHAPE', 'EDGE_TARGET_ARROW_SIZE', 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'EDGE_TOOLTIP', 'EDGE_TRANSPARENCY', 'EDGE_UNSELECTED_PAINT', 'EDGE_VISIBLE', 'EDGE_WIDTH', 'EDGE_Z_ORDER', 'NETWORK', 'NETWORK_ANNOTATION_SELECTION', 'NETWORK_BACKGROUND_PAINT', 'NETWORK_CENTER_X_LOCATION', 'NETWORK_CENTER_Y_LOCATION', 'NETWORK_CENTER_Z_LOCATION', 'NETWORK_DEPTH', 'NETWORK_EDGE_SELECTION', 'NETWORK_FORCE_HIGH_DETAIL', 'NETWORK_HEIGHT', 'NETWORK_NODE_LABEL_SELECTION', 'NETWORK_NODE_SELECTION', 'NETWORK_SCALE_FACTOR', 'NETWORK_SIZE', 'NETWORK_TITLE', 'NETWORK_WIDTH', 'NODE', 'NODE_BORDER_PAINT', 'NODE_BORDER_STROKE', 'NODE_BORDER_TRANSPARENCY', 'NODE_BORDER_WIDTH', 'NODE_CUSTOMGRAPHICS_1', 'NODE_CUSTOMGRAPHICS_2', 'NODE_CUSTOMGRAPHICS_3', 'NODE_CUSTOMGRAPHICS_4', 'NODE_CUSTOMGRAPHICS_5', 'NODE_CUSTOMGRAPHICS_6', 'NODE_CUSTOMGRAPHICS_7', 'NODE_CUSTOMGRAPHICS_8', 'NODE_CUSTOMGRAPHICS_9', 'NODE_CUSTOMGRAPHICS_POSITION_1', 'NODE_CUSTOMGRAPHICS_POSITION_2', 'NODE_CUSTOMGRAPHICS_POSITION_3', 'NODE_CUSTOMGRAPHICS_POSITION_4', 'NODE_CUSTOMGRAPHICS_POSITION_5', 'NODE_CUSTOMGRAPHICS_POSITION_6', 'NODE_CUSTOMGRAPHICS_POSITION_7', 'NODE_CUSTOMGRAPHICS_POSITION_8', 'NODE_CUSTOMGRAPHICS_POSITION_9', 'NODE_CUSTOMGRAPHICS_SIZE_1', 'NODE_CUSTOMGRAPHICS_SIZE_2', 'NODE_CUSTOMGRAPHICS_SIZE_3', 'NODE_CUSTOMGRAPHICS_SIZE_4', 'NODE_CUSTOMGRAPHICS_SIZE_5', 'NODE_CUSTOMGRAPHICS_SIZE_6', 'NODE_CUSTOMGRAPHICS_SIZE_7', 'NODE_CUSTOMGRAPHICS_SIZE_8', 'NODE_CUSTOMGRAPHICS_SIZE_9', 'NODE_CUSTOMPAINT_1', 'NODE_CUSTOMPAINT_2', 'NODE_CUSTOMPAINT_3', 'NODE_CUSTOMPAINT_4', 'NODE_CUSTOMPAINT_5', 'NODE_CUSTOMPAINT_6', 'NODE_CUSTOMPAINT_7', 'NODE_CUSTOMPAINT_8', 'NODE_CUSTOMPAINT_9', 'NODE_DEPTH', 'NODE_FILL_COLOR', 'NODE_HEIGHT', 'NODE_LABEL', 'NODE_LABEL_BACKGROUND_COLOR', 'NODE_LABEL_BACKGROUND_SHAPE', 'NODE_LABEL_BACKGROUND_TRANSPARENCY', 'NODE_LABEL_COLOR', 'NODE_LABEL_FONT_FACE', 'NODE_LABEL_FONT_SIZE', 'NODE_LABEL_POSITION', 'NODE_LABEL_ROTATION', 'NODE_LABEL_TRANSPARENCY', 'NODE_LABEL_WIDTH', 'NODE_NESTED_NETWORK_IMAGE_VISIBLE', 'NODE_PAINT', 'NODE_SELECTED', 'NODE_SELECTED_PAINT', 'NODE_SHAPE', 'NODE_SIZE', 'NODE_TOOLTIP', 'NODE_TRANSPARENCY', 'NODE_VISIBLE', 'NODE_WIDTH', 'NODE_X_LOCATION', 'NODE_Y_LOCATION', 'NODE_Z_LOCATION']
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀReturning 'map_visual_property': {'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_PAINT', 'points': [{'value': 0, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#FF0000'}, {'value': 0.05, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#555555'}]}
# DEBUG:py4...:ǀCalling update_style_mapping('galFiltered Style', {'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_PAINT', 'points': [{'value': 0, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#FF0000'}, {'value': 0.05, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#555555'}]}, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('styles/galFiltered Style/mappings', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/styles/galFiltered%20Style/mappings)
# DEBUG:py4...:ǀǀOK[200], content: [ {
#   "mappingType" : "continuous",
#   "mappingColumn" : "degree.layout",
#   "mappingColumnType" : "Number",
#   "visualProperty" : "NODE_SIZE",
#   "points" : [ {
#     "value" : 1.0,
#     "lesser" : "1.0",
#     "equal" : "40.0",
#     "greater" : "40.0"
#   }, {
#     "value" : 18.0,
#     "lesser" : "150.0",
#     "equal" : "150.0",
#     "greater" : "1.0"
#   } ]
# }, {
#   "mappingType" : "continuous",
#   "mappingColumn" : "gal80Rexp",
#   "mappingColumnType" : "Double",
#   "visualProperty" : "NODE_FILL_COLOR",
#   "points" : [ {
#     "value" : -3.126,
#     "lesser" : "#67A9CF",
#     "equal" : "#67A9CF",
#     "greater" : "#67A9CF"
#   }, {
#     "value" : 0.0,
#     "lesser" : "#F7F7F7",
#     "equal" : "#F7F7F7",
#     "greater" : "#F7F7F7"
#   }, {
#     "value" : 3.126,
#     "lesser" : "#EF8A62",
#     "equal" : "#EF8A62",
#     "greater" : "#EF8A62"
#   } ]
# }, {
#   "mappingType" : "passthrough",
#   "mappingColumn" : "COMMON",
#   "mappingColumnType" : "String",
#   "visualProperty" : "NODE_LABEL"
# }, {
#   "mappingType" : "continuous",
#   "mappingColumn" : "Degree",
#   "mappingColumnType" : "Number",
#   "visualProperty" : "NODE_LABEL_FONT_SIZE",
#   "points" : [ {
#     "value" : 1.0,
#     "lesser" : "1",
#     "equal" : "10",
#     "greater" : "10"
#   }, {
#     "value" : 18.0,
#     "lesser" : "40",
#     "equal" : "40",
#     "greater" : "1"
#   } ]
# } ]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'mappingType': 'continuous', 'mappingColumn': 'degree.layout', 'mappingColumnType': 'Number', 'visualProperty': 'NODE_SIZE', 'points': [{'value': 1.0, 'lesser': '1.0', 'equal': '40.0', 'greater': '40.0'}, {'value': 18.0, 'lesser': '150.0', 'equal': '150.0', 'greater': '1.0'}]}, {'mappingType': 'continuous', 'mappingColumn': 'gal80Rexp', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_FILL_COLOR', 'points': [{'value': -3.126, 'lesser': '#67A9CF', 'equal': '#67A9CF', 'greater': '#67A9CF'}, {'value': 0.0, 'lesser': '#F7F7F7', 'equal': '#F7F7F7', 'greater': '#F7F7F7'}, {'value': 3.126, 'lesser': '#EF8A62', 'equal': '#EF8A62', 'greater': '#EF8A62'}]}, {'mappingType': 'passthrough', 'mappingColumn': 'COMMON', 'mappingColumnType': 'String', 'visualProperty': 'NODE_LABEL'}, {'mappingType': 'continuous', 'mappingColumn': 'Degree', 'mappingColumnType': 'Number', 'visualProperty': 'NODE_LABEL_FONT_SIZE', 'points': [{'value': 1.0, 'lesser': '1', 'equal': '10', 'greater': '10'}, {'value': 18.0, 'lesser': '40', 'equal': '40', 'greater': '1'}]}]
# DEBUG:py4...:ǀǀCalling cyrest_post('styles/galFiltered Style/mappings', body=[{'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_PAINT', 'points': [{'value': 0, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#FF0000'}, {'value': 0.05, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#555555'}]}], base_url='http://127.0.0.1:1234/v1', require_json=False)
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/styles/galFiltered%20Style/mappings), json: [{'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_PAINT', 'points': [{'value': 0, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#FF0000'}, {'value': 0.05, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#555555'}]}]
# DEBUG:py4...:ǀǀCreated[201], content:
# DEBUG:py4...:ǀǀReturning 'cyrest_post': ''
# DEBUG:py4...:ǀReturning 'update_style_mapping': ''
# DEBUG:py4...:Returning 'set_node_border_color_mapping': ''
# DEBUG:py4...:--------------------
# ''

# %% [markdown]
# Note: We are supplying a min and max points, together with four color values. Providing n+2 values will result in assigning “below min” and “above max” mappings (see image).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# …and let’s also map the same gal80RSig values to set the Node Border Widths:

# %% [markdown]
# ## Set Node Border Width
#
# You can set the Border Width by

# %%
p4c.set_node_border_width_mapping('gal80Rsig',[0,0.05], [4,4,4,1],style_name="galFiltered Style")
# Out:
# DEBUG:py4...:Calling set_node_border_width_mapping('gal80Rsig', [0, 0.05], [4, 4, 4, 1], style_name='galFiltered Style')
# DEBUG:py4...:ǀCalling get_table_column_names('node', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀReturning 'get_table_column_names': ['SUID', 'shared name', 'name', 'selected', 'AverageShortestPathLength', 'BetweennessCentrality', 'ClosenessCentrality', 'ClusteringCoefficient', 'Degree', 'Eccentricity', 'IsSingleNode', 'NeighborhoodConnectivity', 'NumberOfDirectedEdges', 'NumberOfUndirectedEdges', 'PartnerOfMultiEdgedNodePairs', 'Radiality', 'SelfLoops', 'Stress', 'TopologicalCoefficient', 'degree.layout', 'COMMON', 'gal1RGexp', 'gal4RGexp', 'gal80Rexp', 'gal1RGsig', 'gal4RGsig', 'gal80Rsig', 'isExcludedFromPaths']
# DEBUG:py4...:ǀCalling map_visual_property('NODE_BORDER_WIDTH', 'gal80Rsig', 'c', [0, 0.05], [4, 4, 4, 1], network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling get_visual_property_names(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling cyrest_get('styles/default/defaults', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/styles/default/defaults)
# DEBUG:py4...:ǀǀǀOK[200], content: {
#   "defaults" : [ {
#     "visualProperty" : "COMPOUND_NODE_PADDING",
#     "value" : 10.0
#   }, {
#     "visualProperty" : "COMPOUND_NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "DING_RENDERING_ENGINE_ROOT",
#     "value" : "org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@4823dee5"
#   }, {
#     "visualProperty" : "EDGE",
#     "value" : "DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)"
#   }, {
#     "visualProperty" : "EDGE_BEND",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_CURVED",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_LABEL_AUTOROTATE",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_COLOR",
#     "value" : "#B6B6B6"
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_LABEL_BACKGROUND_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,10"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_SIZE",
#     "value" : 10
#   }, {
#     "visualProperty" : "EDGE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "EDGE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "EDGE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "EDGE_PAINT",
#     "value" : "#323232"
#   }, {
#     "visualProperty" : "EDGE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_STACKING",
#     "value" : "AUTO_BEND"
#   }, {
#     "visualProperty" : "EDGE_STACKING_DENSITY",
#     "value" : 0.5
#   }, {
#     "visualProperty" : "EDGE_STROKE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_STROKE_UNSELECTED_PAINT",
#     "value" : "#666666"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_UNSELECTED_PAINT",
#     "value" : "#404040"
#   }, {
#     "visualProperty" : "EDGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_WIDTH",
#     "value" : 3.0
#   }, {
#     "visualProperty" : "EDGE_Z_ORDER",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK",
#     "value" : "DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)"
#   }, {
#     "visualProperty" : "NETWORK_ANNOTATION_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_BACKGROUND_PAINT",
#     "value" : "#FFFFFF"
#   }, {
#     "visualProperty" : "NETWORK_CENTER_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Z_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_EDGE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_FORCE_HIGH_DETAIL",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_HEIGHT",
#     "value" : 400.0
#   }, {
#     "visualProperty" : "NETWORK_NODE_LABEL_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_NODE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_SCALE_FACTOR",
#     "value" : 1.0
#   }, {
#     "visualProperty" : "NETWORK_SIZE",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NETWORK_TITLE",
#     "value" : ""
#   }, {
#     "visualProperty" : "NETWORK_WIDTH",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NODE",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)"
#   }, {
#     "visualProperty" : "NODE_BORDER_PAINT",
#     "value" : "#006699"
#   }, {
#     "visualProperty" : "NODE_BORDER_STROKE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "NODE_BORDER_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_BORDER_WIDTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_1",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_2",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_3",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_4",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_5",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_6",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_7",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_8",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_9",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_1",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_2",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_3",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_4",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_5",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_6",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_7",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_8",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_9",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_1",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_2",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_3",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_4",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_5",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_6",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_7",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_8",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_9",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_1",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_1, name=Node Custom Paint 1)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_2",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_2, name=Node Custom Paint 2)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_3",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_3, name=Node Custom Paint 3)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_4",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_4, name=Node Custom Paint 4)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_5",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_5, name=Node Custom Paint 5)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_6",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_6, name=Node Custom Paint 6)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_7",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_7, name=Node Custom Paint 7)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_8",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_8, name=Node Custom Paint 8)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_9",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_9, name=Node Custom Paint 9)"
#   }, {
#     "visualProperty" : "NODE_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_FILL_COLOR",
#     "value" : "#33FFFF"
#   }, {
#     "visualProperty" : "NODE_HEIGHT",
#     "value" : 30.0
#   }, {
#     "visualProperty" : "NODE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_COLOR",
#     "value" : "#B6B6B6"
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "NODE_LABEL_BACKGROUND_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_COLOR",
#     "value" : "#333333"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,12"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_SIZE",
#     "value" : 12
#   }, {
#     "visualProperty" : "NODE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "NODE_NESTED_NETWORK_IMAGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_PAINT",
#     "value" : "#1E90FF"
#   }, {
#     "visualProperty" : "NODE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "NODE_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "NODE_SIZE",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_WIDTH",
#     "value" : 70.0
#   }, {
#     "visualProperty" : "NODE_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Z_LOCATION",
#     "value" : 0.0
#   } ]
# }
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': {'defaults': [{'visualProperty': 'COMPOUND_NODE_PADDING', 'value': 10.0}, {'visualProperty': 'COMPOUND_NODE_SHAPE', 'value': 'ROUND_RECTANGLE'}, {'visualProperty': 'DING_RENDERING_ENGINE_ROOT', 'value': 'org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@4823dee5'}, {'visualProperty': 'EDGE', 'value': 'DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)'}, {'visualProperty': 'EDGE_BEND', 'value': ''}, {'visualProperty': 'EDGE_CURVED', 'value': True}, {'visualProperty': 'EDGE_LABEL', 'value': ''}, {'visualProperty': 'EDGE_LABEL_AUTOROTATE', 'value': False}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_COLOR', 'value': '#B6B6B6'}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_LABEL_BACKGROUND_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_COLOR', 'value': '#000000'}, {'visualProperty': 'EDGE_LABEL_FONT_FACE', 'value': 'Dialog.plain,plain,10'}, {'visualProperty': 'EDGE_LABEL_FONT_SIZE', 'value': 10}, {'visualProperty': 'EDGE_LABEL_POSITION', 'value': 'C,C,c,0.00,0.00'}, {'visualProperty': 'EDGE_LABEL_ROTATION', 'value': 0.0}, {'visualProperty': 'EDGE_LABEL_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_WIDTH', 'value': 200.0}, {'visualProperty': 'EDGE_LINE_TYPE', 'value': 'SOLID'}, {'visualProperty': 'EDGE_PAINT', 'value': '#323232'}, {'visualProperty': 'EDGE_SELECTED', 'value': False}, {'visualProperty': 'EDGE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_STACKING', 'value': 'AUTO_BEND'}, {'visualProperty': 'EDGE_STACKING_DENSITY', 'value': 0.5}, {'visualProperty': 'EDGE_STROKE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_STROKE_UNSELECTED_PAINT', 'value': '#666666'}, {'visualProperty': 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_TARGET_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_TARGET_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_TOOLTIP', 'value': ''}, {'visualProperty': 'EDGE_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#404040'}, {'visualProperty': 'EDGE_VISIBLE', 'value': True}, {'visualProperty': 'EDGE_WIDTH', 'value': 3.0}, {'visualProperty': 'EDGE_Z_ORDER', 'value': 0.0}, {'visualProperty': 'NETWORK', 'value': 'DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)'}, {'visualProperty': 'NETWORK_ANNOTATION_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_BACKGROUND_PAINT', 'value': '#FFFFFF'}, {'visualProperty': 'NETWORK_CENTER_X_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Y_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Z_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_DEPTH', 'value': 0.0}, {'visualProperty': 'NETWORK_EDGE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_FORCE_HIGH_DETAIL', 'value': False}, {'visualProperty': 'NETWORK_HEIGHT', 'value': 400.0}, {'visualProperty': 'NETWORK_NODE_LABEL_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_NODE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_SCALE_FACTOR', 'value': 1.0}, {'visualProperty': 'NETWORK_SIZE', 'value': 550.0}, {'visualProperty': 'NETWORK_TITLE', 'value': ''}, {'visualProperty': 'NETWORK_WIDTH', 'value': 550.0}, {'visualProperty': 'NODE', 'value': 'DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)'}, {'visualProperty': 'NODE_BORDER_PAINT', 'value': '#006699'}, {'visualProperty': 'NODE_BORDER_STROKE', 'value': 'SOLID'}, {'visualProperty': 'NODE_BORDER_TRANSPARENCY', 'value': 255}, {'visualProperty': 'NODE_BORDER_ ...
# DEBUG:py4...:ǀǀReturning 'get_visual_property_names': ['COMPOUND_NODE_PADDING', 'COMPOUND_NODE_SHAPE', 'DING_RENDERING_ENGINE_ROOT', 'EDGE', 'EDGE_BEND', 'EDGE_CURVED', 'EDGE_LABEL', 'EDGE_LABEL_AUTOROTATE', 'EDGE_LABEL_BACKGROUND_COLOR', 'EDGE_LABEL_BACKGROUND_SHAPE', 'EDGE_LABEL_BACKGROUND_TRANSPARENCY', 'EDGE_LABEL_COLOR', 'EDGE_LABEL_FONT_FACE', 'EDGE_LABEL_FONT_SIZE', 'EDGE_LABEL_POSITION', 'EDGE_LABEL_ROTATION', 'EDGE_LABEL_TRANSPARENCY', 'EDGE_LABEL_WIDTH', 'EDGE_LINE_TYPE', 'EDGE_PAINT', 'EDGE_SELECTED', 'EDGE_SELECTED_PAINT', 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'EDGE_SOURCE_ARROW_SHAPE', 'EDGE_SOURCE_ARROW_SIZE', 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'EDGE_STACKING', 'EDGE_STACKING_DENSITY', 'EDGE_STROKE_SELECTED_PAINT', 'EDGE_STROKE_UNSELECTED_PAINT', 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'EDGE_TARGET_ARROW_SHAPE', 'EDGE_TARGET_ARROW_SIZE', 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'EDGE_TOOLTIP', 'EDGE_TRANSPARENCY', 'EDGE_UNSELECTED_PAINT', 'EDGE_VISIBLE', 'EDGE_WIDTH', 'EDGE_Z_ORDER', 'NETWORK', 'NETWORK_ANNOTATION_SELECTION', 'NETWORK_BACKGROUND_PAINT', 'NETWORK_CENTER_X_LOCATION', 'NETWORK_CENTER_Y_LOCATION', 'NETWORK_CENTER_Z_LOCATION', 'NETWORK_DEPTH', 'NETWORK_EDGE_SELECTION', 'NETWORK_FORCE_HIGH_DETAIL', 'NETWORK_HEIGHT', 'NETWORK_NODE_LABEL_SELECTION', 'NETWORK_NODE_SELECTION', 'NETWORK_SCALE_FACTOR', 'NETWORK_SIZE', 'NETWORK_TITLE', 'NETWORK_WIDTH', 'NODE', 'NODE_BORDER_PAINT', 'NODE_BORDER_STROKE', 'NODE_BORDER_TRANSPARENCY', 'NODE_BORDER_WIDTH', 'NODE_CUSTOMGRAPHICS_1', 'NODE_CUSTOMGRAPHICS_2', 'NODE_CUSTOMGRAPHICS_3', 'NODE_CUSTOMGRAPHICS_4', 'NODE_CUSTOMGRAPHICS_5', 'NODE_CUSTOMGRAPHICS_6', 'NODE_CUSTOMGRAPHICS_7', 'NODE_CUSTOMGRAPHICS_8', 'NODE_CUSTOMGRAPHICS_9', 'NODE_CUSTOMGRAPHICS_POSITION_1', 'NODE_CUSTOMGRAPHICS_POSITION_2', 'NODE_CUSTOMGRAPHICS_POSITION_3', 'NODE_CUSTOMGRAPHICS_POSITION_4', 'NODE_CUSTOMGRAPHICS_POSITION_5', 'NODE_CUSTOMGRAPHICS_POSITION_6', 'NODE_CUSTOMGRAPHICS_POSITION_7', 'NODE_CUSTOMGRAPHICS_POSITION_8', 'NODE_CUSTOMGRAPHICS_POSITION_9', 'NODE_CUSTOMGRAPHICS_SIZE_1', 'NODE_CUSTOMGRAPHICS_SIZE_2', 'NODE_CUSTOMGRAPHICS_SIZE_3', 'NODE_CUSTOMGRAPHICS_SIZE_4', 'NODE_CUSTOMGRAPHICS_SIZE_5', 'NODE_CUSTOMGRAPHICS_SIZE_6', 'NODE_CUSTOMGRAPHICS_SIZE_7', 'NODE_CUSTOMGRAPHICS_SIZE_8', 'NODE_CUSTOMGRAPHICS_SIZE_9', 'NODE_CUSTOMPAINT_1', 'NODE_CUSTOMPAINT_2', 'NODE_CUSTOMPAINT_3', 'NODE_CUSTOMPAINT_4', 'NODE_CUSTOMPAINT_5', 'NODE_CUSTOMPAINT_6', 'NODE_CUSTOMPAINT_7', 'NODE_CUSTOMPAINT_8', 'NODE_CUSTOMPAINT_9', 'NODE_DEPTH', 'NODE_FILL_COLOR', 'NODE_HEIGHT', 'NODE_LABEL', 'NODE_LABEL_BACKGROUND_COLOR', 'NODE_LABEL_BACKGROUND_SHAPE', 'NODE_LABEL_BACKGROUND_TRANSPARENCY', 'NODE_LABEL_COLOR', 'NODE_LABEL_FONT_FACE', 'NODE_LABEL_FONT_SIZE', 'NODE_LABEL_POSITION', 'NODE_LABEL_ROTATION', 'NODE_LABEL_TRANSPARENCY', 'NODE_LABEL_WIDTH', 'NODE_NESTED_NETWORK_IMAGE_VISIBLE', 'NODE_PAINT', 'NODE_SELECTED', 'NODE_SELECTED_PAINT', 'NODE_SHAPE', 'NODE_SIZE', 'NODE_TOOLTIP', 'NODE_TRANSPARENCY', 'NODE_VISIBLE', 'NODE_WIDTH', 'NODE_X_LOCATION', 'NODE_Y_LOCATION', 'NODE_Z_LOCATION']
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀReturning 'map_visual_property': {'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_WIDTH', 'points': [{'value': 0, 'lesser': '4', 'equal': '4', 'greater': '4'}, {'value': 0.05, 'lesser': '4', 'equal': '4', 'greater': '1'}]}
# DEBUG:py4...:ǀCalling update_style_mapping('galFiltered Style', {'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_WIDTH', 'points': [{'value': 0, 'lesser': '4', 'equal': '4', 'greater': '4'}, {'value': 0.05, 'lesser': '4', 'equal': '4', 'greater': '1'}]}, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('styles/galFiltered Style/mappings', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/styles/galFiltered%20Style/mappings)
# DEBUG:py4...:ǀǀOK[200], content: [ {
#   "mappingType" : "continuous",
#   "mappingColumn" : "degree.layout",
#   "mappingColumnType" : "Number",
#   "visualProperty" : "NODE_SIZE",
#   "points" : [ {
#     "value" : 1.0,
#     "lesser" : "1.0",
#     "equal" : "40.0",
#     "greater" : "40.0"
#   }, {
#     "value" : 18.0,
#     "lesser" : "150.0",
#     "equal" : "150.0",
#     "greater" : "1.0"
#   } ]
# }, {
#   "mappingType" : "continuous",
#   "mappingColumn" : "gal80Rexp",
#   "mappingColumnType" : "Double",
#   "visualProperty" : "NODE_FILL_COLOR",
#   "points" : [ {
#     "value" : -3.126,
#     "lesser" : "#67A9CF",
#     "equal" : "#67A9CF",
#     "greater" : "#67A9CF"
#   }, {
#     "value" : 0.0,
#     "lesser" : "#F7F7F7",
#     "equal" : "#F7F7F7",
#     "greater" : "#F7F7F7"
#   }, {
#     "value" : 3.126,
#     "lesser" : "#EF8A62",
#     "equal" : "#EF8A62",
#     "greater" : "#EF8A62"
#   } ]
# }, {
#   "mappingType" : "passthrough",
#   "mappingColumn" : "COMMON",
#   "mappingColumnType" : "String",
#   "visualProperty" : "NODE_LABEL"
# }, {
#   "mappingType" : "continuous",
#   "mappingColumn" : "Degree",
#   "mappingColumnType" : "Number",
#   "visualProperty" : "NODE_LABEL_FONT_SIZE",
#   "points" : [ {
#     "value" : 1.0,
#     "lesser" : "1",
#     "equal" : "10",
#     "greater" : "10"
#   }, {
#     "value" : 18.0,
#     "lesser" : "40",
#     "equal" : "40",
#     "greater" : "1"
#   } ]
# }, {
#   "mappingType" : "continuous",
#   "mappingColumn" : "gal80Rsig",
#   "mappingColumnType" : "Double",
#   "visualProperty" : "NODE_BORDER_PAINT",
#   "points" : [ {
#     "value" : 0.0,
#     "lesser" : "#FF0000",
#     "equal" : "#FF0000",
#     "greater" : "#FF0000"
#   }, {
#     "value" : 0.05,
#     "lesser" : "#FF0000",
#     "equal" : "#FF0000",
#     "greater" : "#555555"
#   } ]
# } ]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'mappingType': 'continuous', 'mappingColumn': 'degree.layout', 'mappingColumnType': 'Number', 'visualProperty': 'NODE_SIZE', 'points': [{'value': 1.0, 'lesser': '1.0', 'equal': '40.0', 'greater': '40.0'}, {'value': 18.0, 'lesser': '150.0', 'equal': '150.0', 'greater': '1.0'}]}, {'mappingType': 'continuous', 'mappingColumn': 'gal80Rexp', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_FILL_COLOR', 'points': [{'value': -3.126, 'lesser': '#67A9CF', 'equal': '#67A9CF', 'greater': '#67A9CF'}, {'value': 0.0, 'lesser': '#F7F7F7', 'equal': '#F7F7F7', 'greater': '#F7F7F7'}, {'value': 3.126, 'lesser': '#EF8A62', 'equal': '#EF8A62', 'greater': '#EF8A62'}]}, {'mappingType': 'passthrough', 'mappingColumn': 'COMMON', 'mappingColumnType': 'String', 'visualProperty': 'NODE_LABEL'}, {'mappingType': 'continuous', 'mappingColumn': 'Degree', 'mappingColumnType': 'Number', 'visualProperty': 'NODE_LABEL_FONT_SIZE', 'points': [{'value': 1.0, 'lesser': '1', 'equal': '10', 'greater': '10'}, {'value': 18.0, 'lesser': '40', 'equal': '40', 'greater': '1'}]}, {'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_PAINT', 'points': [{'value': 0.0, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#FF0000'}, {'value': 0.05, 'lesser': '#FF0000', 'equal': '#FF0000', 'greater': '#555555'}]}]
# DEBUG:py4...:ǀǀCalling cyrest_post('styles/galFiltered Style/mappings', body=[{'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_WIDTH', 'points': [{'value': 0, 'lesser': '4', 'equal': '4', 'greater': '4'}, {'value': 0.05, 'lesser': '4', 'equal': '4', 'greater': '1'}]}], base_url='http://127.0.0.1:1234/v1', require_json=False)
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/styles/galFiltered%20Style/mappings), json: [{'mappingType': 'continuous', 'mappingColumn': 'gal80Rsig', 'mappingColumnType': 'Double', 'visualProperty': 'NODE_BORDER_WIDTH', 'points': [{'value': 0, 'lesser': '4', 'equal': '4', 'greater': '4'}, {'value': 0.05, 'lesser': '4', 'equal': '4', 'greater': '1'}]}]
# DEBUG:py4...:ǀǀCreated[201], content:
# DEBUG:py4...:ǀǀReturning 'cyrest_post': ''
# DEBUG:py4...:ǀReturning 'update_style_mapping': ''
# DEBUG:py4...:Returning 'set_node_border_width_mapping': ''
# DEBUG:py4...:--------------------
# ''

# %% [markdown]
# Note: We are supplying the same min and max points, together with just two width values. Providing n values will result in 1:1 assignments.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Layouts
#
# An important aspect of network visualization is the layout, meaning the positioning of nodes and edges. Our network had a preset layout in the original file you imported, but this can be changed.
#
# *   Let’s change the layout to **Degree Sorted Circle Layout** by

# %%
p4c.layout_network('degree-circle')
# Out:
# DEBUG:py4...:Calling layout_network('degree-circle')
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀCalling commands_post('layout degree-circle network="SUID:308"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/layout/degree-circle), json: {'network': 'SUID:308'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {}
# DEBUG:py4...:Returning 'layout_network': {}
# DEBUG:py4...:--------------------
# {}

# %%
from IPython.display import Image
p4c.export_image(filename='degree-circle.png')
p4c.sandbox_get_from('degree-circle.png')
Image('degree-circle.png')
# Out:
# DEBUG:py4...:Calling export_image(filename='degree-circle.png')
# DEBUG:py4...:ǀCalling get_network_view_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_views(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/308/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [3968]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [3968]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [3968]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 3968
# DEBUG:py4...:ǀCalling cytoscape_version_info(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('version', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/version)
# DEBUG:py4...:ǀǀOK[200], content: {"apiVersion":"v1","cytoscapeVersion":"3.10.2"}
# DEBUG:py4...:ǀǀReturning 'cyrest_get': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2'}
# DEBUG:py4...:ǀHTTP version()
# DEBUG:py4...:ǀOK[200], content: {"jupyterBridgeVersion":"0.0.2"}
# DEBUG:py4...:ǀReturning 'cytoscape_version_info': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:ǀCalling sandbox_get_file_info('degree-circle.png', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('filetransfer getFileInfo sandboxName="default_sandbox" fileName="degree-circle.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/getFileInfo), json: {'sandboxName': 'default_sandbox', 'fileName': 'degree-circle.png'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png","modifiedTime":"","isFile":false},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀReturning 'sandbox_get_file_info': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀCalling commands_post('view export png Zoom="100" outputFile="C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png" view="SUID:3968"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/view/export%20png), json: {'Zoom': '100', 'outputFile': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png', 'view': 'SUID:3968'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"file":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png'}
# DEBUG:py4...:Returning 'export_image': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png'}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling sandbox_get_from('degree-circle.png')
# DEBUG:py4...:ǀCalling commands_post('filetransfer fromSandbox sandboxName="default_sandbox" fileName="degree-circle.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/fromSandbox), json: {'sandboxName': 'default_sandbox', 'fileName': 'degree-circle.png'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png","modifiedTime":"2024-12-17 08:28:01.0619","fileByteCount":142206,"fileBase64":"..."},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png', 'modifiedTime': '2024-12-17 08:28:01.0619', 'fileByteCount': 142206, 'fileBase64': '...'}
# DEBUG:py4...:Returning 'sandbox_get_from': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\degree-circle.png', 'modifiedTime': '2024-12-17 08:28:01.0619', 'fileByteCount': 142206}
# DEBUG:py4...:--------------------

# %% [markdown]
# In this layout, nodes are sorted by degree (connectedness), with the highest degree node at the 6 o’clock position, and remaining nodes are sorted counter clock-wise based on decreasing degree.
#
# For this network, a degree-sorted circle layout may not be the most effective. Instead, let’s try a force-directed layout instead, which may work better with this network.

# %%
p4c.layout_network('force-directed')
# Out:
# DEBUG:py4...:Calling layout_network('force-directed')
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀCalling commands_post('layout force-directed network="SUID:308"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/layout/force-directed), json: {'network': 'SUID:308'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {}
# DEBUG:py4...:Returning 'layout_network': {}
# DEBUG:py4...:--------------------
# {}

# %%
p4c.export_image(filename='force-directed.png')
p4c.sandbox_get_from('force-directed.png')
Image('force-directed.png')
# Out:
# DEBUG:py4...:Calling export_image(filename='force-directed.png')
# DEBUG:py4...:ǀCalling get_network_view_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_views(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/308/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [3968]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [3968]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [3968]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 3968
# DEBUG:py4...:ǀCalling cytoscape_version_info(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('version', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/version)
# DEBUG:py4...:ǀǀOK[200], content: {"apiVersion":"v1","cytoscapeVersion":"3.10.2"}
# DEBUG:py4...:ǀǀReturning 'cyrest_get': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2'}
# DEBUG:py4...:ǀHTTP version()
# DEBUG:py4...:ǀOK[200], content: {"jupyterBridgeVersion":"0.0.2"}
# DEBUG:py4...:ǀReturning 'cytoscape_version_info': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:ǀCalling sandbox_get_file_info('force-directed.png', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('filetransfer getFileInfo sandboxName="default_sandbox" fileName="force-directed.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/getFileInfo), json: {'sandboxName': 'default_sandbox', 'fileName': 'force-directed.png'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png","modifiedTime":"","isFile":false},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀReturning 'sandbox_get_file_info': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀCalling commands_post('view export png Zoom="100" outputFile="C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png" view="SUID:3968"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/view/export%20png), json: {'Zoom': '100', 'outputFile': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png', 'view': 'SUID:3968'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"file":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png'}
# DEBUG:py4...:Returning 'export_image': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png'}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling sandbox_get_from('force-directed.png')
# DEBUG:py4...:ǀCalling commands_post('filetransfer fromSandbox sandboxName="default_sandbox" fileName="force-directed.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/fromSandbox), json: {'sandboxName': 'default_sandbox', 'fileName': 'force-directed.png'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png","modifiedTime":"2024-12-17 08:31:03.0107","fileByteCount":59288,"fileBase64":"...\u003d"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png', 'modifiedTime': '2024-12-17 08:31:03.0107', 'fileByteCount': 59288, 'fileBase64': '...'}
# DEBUG:py4...:Returning 'sandbox_get_from': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\force-directed.png', 'modifiedTime': '2024-12-17 08:31:03.0107', 'fileByteCount': 59288}
# DEBUG:py4...:--------------------

# %% [markdown]
# Cytoscape supports many different layout algorithms, described in detail in the [Cytoscape manual](http://manual.cytoscape.org/en/stable/Navigation_and_Layout.html?highlight=layout#automatic-layout-algorithms).
#
# ## Select Nodes
#
# Cytoscape allows you to easily filter and select nodes and edges based on data attributes. Next, we will select a subset of nodes with high expression in the gal80 knockout:
#
# Let’s select a subset of nodes with high expression in the gal80 knockout:

# %%
p4c.create_column_filter('myFilter', 'gal80Rexp', 2.00, "GREATER_THAN")
# Out:
# DEBUG:py4...:Calling create_column_filter('myFilter', 'gal80Rexp', 2.0, 'GREATER_THAN')
# DEBUG:py4...:ǀCalling set_current_network(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling commands_post('network set current network="SUID:308"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/set%20current), json: {'network': 'SUID:308'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {}
# DEBUG:py4...:ǀReturning 'set_current_network': {}
# DEBUG:py4...:ǀCalling get_table_column_names('node', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀReturning 'get_table_column_names': ['SUID', 'shared name', 'name', 'selected', 'AverageShortestPathLength', 'BetweennessCentrality', 'ClosenessCentrality', 'ClusteringCoefficient', 'Degree', 'Eccentricity', 'IsSingleNode', 'NeighborhoodConnectivity', 'NumberOfDirectedEdges', 'NumberOfUndirectedEdges', 'PartnerOfMultiEdgedNodePairs', 'Radiality', 'SelfLoops', 'Stress', 'TopologicalCoefficient', 'degree.layout', 'COMMON', 'gal1RGexp', 'gal4RGexp', 'gal80Rexp', 'gal1RGsig', 'gal4RGsig', 'gal80Rsig', 'isExcludedFromPaths']
# DEBUG:py4...:ǀCalling get_table_columns('node', 'gal80Rexp', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling get_table_column_types('node', namespace='default', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀǀReturning 'get_table_column_types': {'SUID': 'Long', 'shared name': 'String', 'name': 'String', 'selected': 'Boolean', 'AverageShortestPathLength': 'Double', 'BetweennessCentrality': 'Double', 'ClosenessCentrality': 'Double', 'ClusteringCoefficient': 'Double', 'Degree': 'Integer', 'Eccentricity': 'Integer', 'IsSingleNode': 'Boolean', 'NeighborhoodConnectivity': 'Double', 'NumberOfDirectedEdges': 'Integer', 'NumberOfUndirectedEdges': 'Integer', 'PartnerOfMultiEdgedNodePairs': 'Integer', 'Radiality': 'Double', 'SelfLoops': 'Integer', 'Stress': 'Long', 'TopologicalCoefficient': 'Double', 'degree.layout': 'Integer', 'COMMON': 'String', 'gal1RGexp': 'Double', 'gal4RGexp': 'Double', 'gal80Rexp': 'Double', 'gal1RGsig': 'Double', 'gal4RGsig': 'Double', 'gal80Rsig': 'Double', 'isExcludedFromPaths': 'Boolean'}
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns/SUID', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns/SUID)
# DEBUG:py4...:ǀǀOK[200], content: {"name":"SUID","values":[513,515,517,519,521,523,525,527,529,531,533,535,537,539,541,543,545,547,549,551,553,555,557,559,561,563,565,567,569,571,573,575,577,579,581,583,585,587,589,591,593,595,597,599,601,603,605,607,609,611,613,615,617,619,621,623,625,627,629,631,633,635,637,639,641,643,645,647,649,651,653,655,657,659,661,663,665,667,669,671,673,675,677,679,681,683,685,687,689,691,693,695,697,699,701,703,705,707,709,711,713,715,717,719,721,723,725,727,729,731,733,735,737,739,741,743,745,747,749,751,753,755,757,759,761,763,765,767,769,771,773,775,777,779,781,783,785,787,789,791,793,795,797,799,801,803,805,807,809,811,813,815,817,819,821,823,825,827,829,831,833,835,837,839,841,843,845,335,847,337,849,339,851,341,853,343,855,345,857,347,859,349,861,351,863,353,865,355,867,357,869,359,871,361,873,363,875,365,877,367,879,369,881,371,883,373,885,375,887,377,889,379,891,381,893,383,895,385,897,387,899,389,901,391,903,393,905,395,907,397,909,399,911,401,913,403,915,405,917,407,919,409,921,411,923,413,925,415,927,417,929,419,931,421,933,423,935,425,937,427,939,429,941,431,943,433,945,435,947,437,949,439,951,441,953,443,955,445,957,447,959,449,961,451,963,453,965,455,967,457,969,459,971,461,973,463,975,465,977,467,979,469,981,471,983,473,985,475,987,477,989,479,991,481,993,483,485,487,489,491,493,495,497,499,501,503,505,507,509,511]}
# DEBUG:py4...:ǀǀReturning 'cyrest_get': {'name': 'SUID', 'values':
{'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:ǀCalling cyrest_post('commands/filter/create', body={'name': 'myFilter', 'json': '{"id": "ColumnFilter", "parameters": {"criterion": [2.0, 3.126], "columnName": "gal80Rexp", "predicate": "GREATER_THAN", "caseSensitive": false, "anyMatch": true, "type": "nodes"}}', 'apply': True}, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/filter/create), json: {'name': 'myFilter', 'json': '{"id": "ColumnFilter", "parameters": {"criterion": [2.0, 3.126], "columnName": "gal80Rexp", "predicate": "GREATER_THAN", "caseSensitive": false, "anyMatch": true, "type": "nodes"}}', 'apply': True}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'cyrest_post': {'data': {}, 'errors': []}
# DEBUG:py4...:ǀCalling cytoscape_version_info(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('version', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/version)
# DEBUG:py4...:ǀǀOK[200], content: {"apiVersion":"v1","cytoscapeVersion":"3.10.2"}
# DEBUG:py4...:ǀǀReturning 'cyrest_get': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2'}
# DEBUG:py4...:ǀHTTP version()
# DEBUG:py4...:ǀOK[200], content: {"jupyterBridgeVersion":"0.0.2"}
# DEBUG:py4...:ǀReturning 'cytoscape_version_info': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:ǀCalling get_selected_nodes(network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀCalling get_selected_node_count(308, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(308, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [308]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [308]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/308/nodes', parameters={'column': 'selected', 'query': 'true'}, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/nodes), params: {'column': 'selected', 'query': 'true'}
# DEBUG:py4...:ǀǀǀOK[200], content: [805,811,817]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [805, 811, 817]
# DEBUG:py4...:ǀǀReturning 'get_selected_node_count': 3
# DEBUG:py4...:ǀǀCalling cyrest_get('networks/308/nodes', parameters={'column': 'selected', 'query': 'true'}, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/nodes), params: {'column': 'selected', 'query': 'true'}
# DEBUG:py4...:ǀǀOK[200], content: [805,811,817]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [805, 811, 817]
# DEBUG:py4...:ǀǀCalling get_table_columns('node', ['name'], 'default', 308, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(308, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [308]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [308]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀCalling get_table_column_types('node', namespace='default', network=308, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling get_network_suid(308, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀǀOK[200], content: [308]
# DEBUG:py4...:ǀǀǀǀǀReturning 'cyrest_get': [308]
# DEBUG:py4...:ǀǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"AverageShortestPathLength","type":"Double","immutable":false,"primaryKey":false},{"name":"BetweennessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClosenessCentrality","type":"Double","immutable":false,"primaryKey":false},{"name":"ClusteringCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"Degree","type":"Integer","immutable":false,"primaryKey":false},{"name":"Eccentricity","type":"Integer","immutable":false,"primaryKey":false},{"name":"IsSingleNode","type":"Boolean","immutable":false,"primaryKey":false},{"name":"NeighborhoodConnectivity","type":"Double","immutable":false,"primaryKey":false},{"name":"NumberOfDirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"NumberOfUndirectedEdges","type":"Integer","immutable":false,"primaryKey":false},{"name":"PartnerOfMultiEdgedNodePairs","type":"Integer","immutable":false,"primaryKey":false},{"name":"Radiality","type":"Double","immutable":false,"primaryKey":false},{"name":"SelfLoops","type":"Integer","immutable":false,"primaryKey":false},{"name":"Stress","type":"Long","immutable":false,"primaryKey":false},{"name":"TopologicalCoefficient","type":"Double","immutable":false,"primaryKey":false},{"name":"degree.layout","type":"Integer","immutable":false,"primaryKey":false},{"name":"COMMON","type":"String","immutable":false,"primaryKey":false},{"name":"gal1RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rexp","type":"Double","immutable":false,"primaryKey":false},{"name":"gal1RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal4RGsig","type":"Double","immutable":false,"primaryKey":false},{"name":"gal80Rsig","type":"Double","immutable":false,"primaryKey":false},{"name":"isExcludedFromPaths","type":"Boolean","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'AverageShortestPathLength', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'BetweennessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClosenessCentrality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'ClusteringCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'Degree', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Eccentricity', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'IsSingleNode', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}, {'name': 'NeighborhoodConnectivity', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfDirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'NumberOfUndirectedEdges', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'PartnerOfMultiEdgedNodePairs', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Radiality', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'SelfLoops', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'Stress', 'type': 'Long', 'immutable': False, 'primaryKey': False}, {'name': 'TopologicalCoefficient', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'degree.layout', 'type': 'Integer', 'immutable': False, 'primaryKey': False}, {'name': 'COMMON', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rexp', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal1RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal4RGsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'gal80Rsig', 'type': 'Double', 'immutable': False, 'primaryKey': False}, {'name': 'isExcludedFromPaths', 'type': 'Boolean', 'immutable': False, 'primaryKey': False}]
# DEBUG:py4...:ǀǀǀReturning 'get_table_column_types': {'SUID': 'Long', 'shared name': 'String', 'name': 'String', 'selected': 'Boolean', 'AverageShortestPathLength': 'Double', 'BetweennessCentrality': 'Double', 'ClosenessCentrality': 'Double', 'ClusteringCoefficient': 'Double', 'Degree': 'Integer', 'Eccentricity': 'Integer', 'IsSingleNode': 'Boolean', 'NeighborhoodConnectivity': 'Double', 'NumberOfDirectedEdges': 'Integer', 'NumberOfUndirectedEdges': 'Integer', 'PartnerOfMultiEdgedNodePairs': 'Integer', 'Radiality': 'Double', 'SelfLoops': 'Integer', 'Stress': 'Long', 'TopologicalCoefficient': 'Double', 'degree.layout': 'Integer', 'COMMON': 'String', 'gal1RGexp': 'Double', 'gal4RGexp': 'Double', 'gal80Rexp': 'Double', 'gal1RGsig': 'Double', 'gal4RGsig': 'Double', 'gal80Rsig': 'Double', 'isExcludedFromPaths': 'Boolean'}
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/308/tables/defaultnode/columns/SUID', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/tables/defaultnode/columns/SUID)
# DEBUG:py4...:ǀǀǀOK[200], content: {"name":"SUID","values":[513,515,517,519,521,523,525,527,529,531,533,535,537,539,541,543,545,547,549,551,553,555,557,559,561,563,565,567,569,571,573,575,577,579,581,583,585,587,589,591,593,595,597,599,601,603,605,607,609,611,613,615,617,619,621,623,625,627,629,631,633,635,637,639,641,643,645,647,649,651,653,655,657,659,661,663,665,667,669,671,673,675,677,679,681,683,685,687,689,691,693,695,697,699,701,703,705,707,709,711,713,715,717,719,721,723,725,727,729,731,733,735,737,739,741,743,745,747,749,751,753,755,757,759,761,763,765,767,769,771,773,775,777,779,781,783,785,787,789,791,793,795,797,799,801,803,805,807,809,811,813,815,817,819,821,823,825,827,829,831,833,835,837,839,841,843,845,335,847,337,849,339,851,341,853,343,855,345,857,347,859,349,861,351,863,353,865,355,867,357,869,359,871,361,873,363,875,365,877,367,879,369,881,371,883,373,885,375,887,377,889,379,891,381,893,383,895,385,897,387,899,389,901,391,903,393,905,395,907,397,909,399,911,401,913,403,915,405,917,407,919,409,921,411,923,413,925,415,927,417,929,419,931,421,933,423,935,425,937,427,939,429,941,431,943,433,945,435,947,437,949,439,951,441,953,443,955,445,957,447,959,449,961,451,963,453,965,455,967,457,969,459,971,461,973,463,975,465,977,467,979,469,981,471,983,473,985,475,987,477,989,479,991,481,993,483,485,487,489,491,493,495,497,499,501,503,505,507,509,511]}
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': {'name': 'SUID', 'values':
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': []
# DEBUG:py4...:ǀǀReturning 'get_selected_edge_count': 0
# DEBUG:py4...:ǀReturning 'get_selected_edges': None
# DEBUG:py4...:Returning 'create_column_filter': {'nodes': ['YBR018C', 'YBR020W', 'YBR019C'], 'edges': None}
# DEBUG:py4...:--------------------
# No edges selected.
# {'nodes': ['YBR018C', 'YBR020W', 'YBR019C'], 'edges': None}

# %% [markdown]
# You should now see only a few nodes in the network selected (highlighted yellow).

# %%
p4c.export_image(filename='column-filter.png')
p4c.sandbox_get_from('column-filter.png')
Image('column-filter.png')
# Out:
# DEBUG:py4...:Calling export_image(filename='column-filter.png')
# DEBUG:py4...:ǀCalling get_network_view_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_views(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/308/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/308/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [3968]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [3968]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [3968]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 3968
# DEBUG:py4...:ǀCalling cytoscape_version_info(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('version', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/version)
# DEBUG:py4...:ǀǀOK[200], content: {"apiVersion":"v1","cytoscapeVersion":"3.10.2"}
# DEBUG:py4...:ǀǀReturning 'cyrest_get': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2'}
# DEBUG:py4...:ǀHTTP version()
# DEBUG:py4...:ǀOK[200], content: {"jupyterBridgeVersion":"0.0.2"}
# DEBUG:py4...:ǀReturning 'cytoscape_version_info': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:ǀCalling sandbox_get_file_info('column-filter.png', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('filetransfer getFileInfo sandboxName="default_sandbox" fileName="column-filter.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/getFileInfo), json: {'sandboxName': 'default_sandbox', 'fileName': 'column-filter.png'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png","modifiedTime":"","isFile":false},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀReturning 'sandbox_get_file_info': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀCalling commands_post('view export png Zoom="100" outputFile="C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png" view="SUID:3968"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/view/export%20png), json: {'Zoom': '100', 'outputFile': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png', 'view': 'SUID:3968'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"file":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png'}
# DEBUG:py4...:Returning 'export_image': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png'}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling sandbox_get_from('column-filter.png')
# DEBUG:py4...:ǀCalling commands_post('filetransfer fromSandbox sandboxName="default_sandbox" fileName="column-filter.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/fromSandbox), json: {'sandboxName': 'default_sandbox', 'fileName': 'column-filter.png'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png","modifiedTime":"2024-12-17 08:50:09.0847","fileByteCount":59191,"fileBase64":"...\u003d\u003d"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png', 'modifiedTime': '2024-12-17 08:50:09.0847', 'fileByteCount': 59191, 'fileBase64': '...'}
# DEBUG:py4...:Returning 'sandbox_get_from': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\column-filter.png', 'modifiedTime': '2024-12-17 08:50:09.0847', 'fileByteCount': 59191}
# DEBUG:py4...:--------------------

# %% [markdown]
# ## Expand Selection and Create New Network
#
# We have now selected only the few top expressing nodes. To see the context of these nodes in the larger network, we can expand the selection to second-degree neighbors:

# %%
p4c.select_first_neighbors()  # first degree
p4c.select_first_neighbors()  # second degree
# Out:
# DEBUG:py4...:Calling select_first_neighbors()
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀCalling commands_post('network select firstNeighbors="any" network=SUID:"308"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/select), json: {'firstNeighbors': 'any', 'network': 'SUID:308'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"nodes":[
#   815,
#   817,
#   805,
#   807,
#   811,
#   813,
#   541
# ], "edges":[]},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'nodes': [815, 817, 805, 807, 811, 813, 541], 'edges': []}
# DEBUG:py4...:Returning 'select_first_neighbors': {'nodes': [815, 817, 805, 807, 811, 813, 541], 'edges': []}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling select_first_neighbors()
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀCalling commands_post('network select firstNeighbors="any" network=SUID:"308"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/select), json: {'firstNeighbors': 'any', 'network': 'SUID:308'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"nodes":[
#   815,
#   527,
#   817,
#   561,
#   665,
#   539,
#   541,
#   767,
#   805,
#   421,
#   807,
#   809,
#   811,
#   683,
#   813,
#   909,
#   749
# ], "edges":[]},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'nodes': [815, 527, 817, 561, 665, 539, 541, 767, 805, 421, 807, 809, 811, 683, 813, 909, 749], 'edges': []}
# DEBUG:py4...:Returning 'select_first_neighbors': {'nodes': [815, 527, 817, 561, 665, 539, 541, 767, 805, 421, 807, 809, 811, 683, 813, 909, 749], 'edges': []}
# DEBUG:py4...:--------------------
# {'nodes': [815,
#   527,
#   817,
#   561,
#   665,
#   539,
#   541,
#   767,
#   805,
#   421,
#   807,
#   809,
#   811,
#   683,
#   813,
#   909,
#   749],
#  'edges': []}

# %%
p4c.create_subnetwork(nodes="selected", subnetwork_name='galFiltered sub')
p4c.layout_network('force-directed')
# Out:
# DEBUG:py4...:Calling create_subnetwork(nodes='selected', subnetwork_name='galFiltered sub')
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 308
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 308}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 308
# DEBUG:py4...:ǀCalling cyrest_post('commands/network/create', body={'source': 'SUID:308', 'excludeEdges': 'false', 'nodeList': 'selected', 'edgeList': 'selected', 'networkName': 'galFiltered sub'}, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/create), json: {'source': 'SUID:308', 'excludeEdges': 'false', 'nodeList': 'selected', 'edgeList': 'selected', 'networkName': 'galFiltered sub'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"network":6176,"view":6323},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'cyrest_post': {'data': {'network': 6176, 'view': 6323}, 'errors': []}
# DEBUG:py4...:Returning 'create_subnetwork': 6176
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling layout_network('force-directed')
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 6176
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 6176}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 6176
# DEBUG:py4...:ǀCalling commands_post('layout force-directed network="SUID:6176"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/layout/force-directed), json: {'network': 'SUID:6176'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {}
# DEBUG:py4...:Returning 'layout_network': {}
# DEBUG:py4...:--------------------
# {}

# %%
p4c.export_image(filename='first-neighbors.png')
p4c.sandbox_get_from('first-neighbors.png')
Image('first-neighbors.png')
# Out:
# DEBUG:py4...:Calling export_image(filename='first-neighbors.png')
# DEBUG:py4...:ǀCalling get_network_view_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_views(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 6176
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 6176}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 6176
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/6176/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/6176/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [6323]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [6323]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [6323]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 6323
# DEBUG:py4...:ǀCalling cytoscape_version_info(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('version', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/version)
# DEBUG:py4...:ǀǀOK[200], content: {"apiVersion":"v1","cytoscapeVersion":"3.10.2"}
# DEBUG:py4...:ǀǀReturning 'cyrest_get': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2'}
# DEBUG:py4...:ǀHTTP version()
# DEBUG:py4...:ǀOK[200], content: {"jupyterBridgeVersion":"0.0.2"}
# DEBUG:py4...:ǀReturning 'cytoscape_version_info': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:ǀCalling sandbox_get_file_info('first-neighbors.png', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('filetransfer getFileInfo sandboxName="default_sandbox" fileName="first-neighbors.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/getFileInfo), json: {'sandboxName': 'default_sandbox', 'fileName': 'first-neighbors.png'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png","modifiedTime":"","isFile":false},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀReturning 'sandbox_get_file_info': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀCalling commands_post('view export png Zoom="100" outputFile="C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png" view="SUID:6323"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/view/export%20png), json: {'Zoom': '100', 'outputFile': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png', 'view': 'SUID:6323'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"file":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png'}
# DEBUG:py4...:Returning 'export_image': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png'}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling sandbox_get_from('first-neighbors.png')
# DEBUG:py4...:ǀCalling commands_post('filetransfer fromSandbox sandboxName="default_sandbox" fileName="first-neighbors.png"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/fromSandbox), json: {'sandboxName': 'default_sandbox', 'fileName': 'first-neighbors.png'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png","modifiedTime":"2024-12-17 08:50:52.0411","fileByteCount":61329,"fileBase64":"..."},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png', 'modifiedTime': '2024-12-17 08:50:52.0411', 'fileByteCount': 61329, 'fileBase64': '...'}
# DEBUG:py4...:Returning 'sandbox_get_from': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\first-neighbors.png', 'modifiedTime': '2024-12-17 08:50:52.0411', 'fileByteCount': 61329}
# DEBUG:py4...:--------------------

# %% [markdown]
# Digging into the biology of this network, it turns out that GAL4 is repressed by GAL80. Both nodes (GAL4 and GAL11) show fairly small changes in expression, and neither change is statistically significant: they are pale blue with thin borders. These slight changes in expression suggest that the critical change affecting the red nodes might be somewhere else in the network, and not either of these nodes. GAL4 interacts with GAL80, which shows a significant level of repression: it is medium blue with a thicker border.
#
# Note that while GAL80 shows evidence of significant repression, most nodes interacting with GAL4 show significant levels of induction: they are rendered as red rectangles. GAL11 is a general transcription co-factor with many interactions.
#
# Putting all of this together, we see that the ___transcriptional activation activity of Gal4 is repressed by Gal80___. So, repression of Gal80 increases the transcriptional activation activity of Gal4. Even though the expression of Gal4 itself did not change much, ___the Gal4 transcripts were much more likely to be active transcription factors when Gal80 was repressed___. This explains why there is so much up-regulation in the vicinity of Gal4.
#
# ## Summary
#
# In summary, we have:
#
# *   Explored a yeast interactome from a transcription factor knockout experiment
# *   Created a visual style using expression value as node color and with border width mapped to significance
# *   Selected high expressing genes and their neighbors and created a new network
#
# Finally, we can now export this network as a publication-quality image….

# %% [markdown]
# ## Saving Results
#
# Cytoscape provides a number of ways to save results and visualizations:
#
# *   As a session:

# %%
p4c.save_session('basic-data-visualization.cys')
# Out:
# DEBUG:py4...:Calling save_session('basic-data-visualization.cys')
# DEBUG:py4...:ǀCalling sandbox_get_file_info('basic-data-visualization.cys', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('filetransfer getFileInfo sandboxName="default_sandbox" fileName="basic-data-visualization.cys"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/getFileInfo), json: {'sandboxName': 'default_sandbox', 'fileName': 'basic-data-visualization.cys'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cys","modifiedTime":"","isFile":false},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cys', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀReturning 'sandbox_get_file_info': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cys', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀCalling commands_post('session save as file="C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox/basic-data-visualization.cys"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/session/save%20as), json: {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox/basic-data-visualization.cys'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {}
# DEBUG:py4...:Returning 'save_session': {}
# DEBUG:py4...:--------------------
# {}

# %% [markdown]
# *   As an image:

# %%
p4c.export_image('basic-data-visualization', type='PDF')

# Note: PNG, SVG, JPEG and PS are also supported
#p4c.export_image('basic-data-visualization', type='PNG')
#p4c.export_image('basic-data-visualization', type='JPEG')
#p4c.export_image('basic-data-visualization', type='SVG')
#p4c.export_image('basic-data-visualization', type='PS')
# Out:
# DEBUG:py4...:Calling export_image('basic-data-visualization', type='PDF')
# DEBUG:py4...:ǀCalling get_network_view_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_views(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 6176
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 6176}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 6176
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/6176/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/6176/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [6323]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [6323]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [6323]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 6323
# DEBUG:py4...:ǀCalling cytoscape_version_info(base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('version', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/version)
# DEBUG:py4...:ǀǀOK[200], content: {"apiVersion":"v1","cytoscapeVersion":"3.10.2"}
# DEBUG:py4...:ǀǀReturning 'cyrest_get': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2'}
# DEBUG:py4...:ǀHTTP version()
# DEBUG:py4...:ǀOK[200], content: {"jupyterBridgeVersion":"0.0.2"}
# DEBUG:py4...:ǀReturning 'cytoscape_version_info': {'apiVersion': 'v1', 'cytoscapeVersion': '3.10.2', 'automationAPIVersion': '1.11.0', 'py4cytoscapeVersion': '1.11.0', 'jupyterBridgeVersion': '0.0.2'}
# DEBUG:py4...:ǀCalling sandbox_get_file_info('basic-data-visualization.pdf', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('filetransfer getFileInfo sandboxName="default_sandbox" fileName="basic-data-visualization.pdf"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/getFileInfo), json: {'sandboxName': 'default_sandbox', 'fileName': 'basic-data-visualization.pdf'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf","modifiedTime":"","isFile":false},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀReturning 'sandbox_get_file_info': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀCalling commands_post('view export pdf Zoom="100" outputFile="C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf" view="SUID:6323"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/view/export%20pdf), json: {'Zoom': '100', 'outputFile': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf', 'view': 'SUID:6323'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"file":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf'}
# DEBUG:py4...:Returning 'export_image': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf'}
# DEBUG:py4...:--------------------
# {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.pdf'}

# %% [markdown]
# *   To a public repository:
#
# ```
# p4c.export_network_to_ndex('userid', 'password', True)
# ```
#
# *   As a graph format file (Formats: “CX JSON”, “Cytoscape.js JSON”, “GraphML”, “XGMML”, “SIF”,…):

# %%
p4c.export_network('basic-data-visualization', 'CX')

# Note: cyjs, graphML, xGMML and SIF are also supported
#p4c.export_network('basic-data-visualization', 'cyjs')
#p4c.export_network('basic-data-visualization', 'graphML')
#p4c.export_network('basic-data-visualization', 'xGMML')
#p4c.export_network('basic-data-visualization', 'SIF')
# Out:
# DEBUG:py4...:Calling export_network('basic-data-visualization', 'CX')
# DEBUG:py4...:ǀCalling sandbox_get_file_info('basic-data-visualization.cx', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('filetransfer getFileInfo sandboxName="default_sandbox" fileName="basic-data-visualization.cx"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/filetransfer/getFileInfo), json: {'sandboxName': 'default_sandbox', 'fileName': 'basic-data-visualization.cx'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": {"filePath":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx","modifiedTime":"","isFile":false},
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀReturning 'sandbox_get_file_info': {'filePath': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx', 'modifiedTime': '', 'isFile': False}
# DEBUG:py4...:ǀCalling commands_post('network export options="CX" OutputFile="C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/export), json: {'options': 'CX', 'OutputFile': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"file":"C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx"},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx'}
# DEBUG:py4...:Returning 'export_network': {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx'}
# DEBUG:py4...:--------------------
# {'file': 'C:\\Users\\ADMIN\\CytoscapeConfiguration\\filetransfer\\default_sandbox\\basic-data-visualization.cx'}
